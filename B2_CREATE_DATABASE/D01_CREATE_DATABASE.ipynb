# %%
import pandas
import sqlite3
banco=sqlite3.connect('../comercial_database.db')
cursor=banco.cursor()

# %%
#delet
command="""DROP TABLE ORDER_MAIN"""
cursor.execute(command)

# %%
#check tables
command=""" SELECT name FROM sqlite_schema"""
cursor.execute(command)
cursor.fetchall()
# Out:
# [('PRODUCTS',),
#  ('sqlite_autoindex_PRODUCTS_1',),
#  ('TAB_PRICE',),
#  ('sqlite_autoindex_TAB_PRICE_1',),
#  ('SALESMAN',),
#  ('sqlite_autoindex_SALESMAN_1',),
#  ('ORDER_ITEM',),
#  ('sqlite_autoindex_ORDER_ITEM_1',),
#  ('CLIENTS',),
#  ('sqlite_autoindex_CLIENTS_1',),
#  ('ORDER_MAIN',),
#  ('sqlite_autoindex_ORDER_MAIN_1',)]

# %%
#check register
command="""SELECT * FROM CLIENTS"""
cursor.execute(command)
cursor.fetchall()
# Out:
# [('10001-001',
#   'Genius Inc. 032',
#   'D',
#   201,
#   '+001 100 232-3005',
#   'Genius_Inc._032@outlook.com',
#   20080501,
#   10001,
#   'NY'),
#  ('10001-002',
#   'Father And Sons Tech 044',
#   'C',
#   201,
#   '+001 100 936-9662',
#   'Father_And_Sons_Tech_044@outlook.com',
#   20030303,
#   10001,
#   'NY'),
#  ('10001-003',
#   'Alpha Solutions 090',
#   'D',
#   201,
#   '+001 100 611-2445',
#   'Alpha_Solutions_090@outlook.com',
#   20140605,
#   10001,
#   'NY'),
#  ('10001-004',
#   'Digital Corporation 096',
#   'D',
#   201,
#   '+001 100 684-2310',
#   'Digital_Corporation_096@outlook.com',
#   20200301,
#   10001,
#   'NY'),
#  ('10001-005',
#   'Beta Electronics 004',
#   'A',
#   201,
#   '+001 100 170-6120',
#   'Beta_Electronics_004@outlook.com',
#   20121114,
#   10001,
#   'NY'),
#  ('10001-006',
#   'Father And Sons Corporation 033',
#   'D',
#   201,
#   '+001 100 951-2014',
#   'Father_And_Sons_Corporation_033@outlook.com',
#   20180707,
#   10001,
#   'NY'),
#  ('10001-007',
#   'Father And Sons S.A 010',
#   'D',
#   201,
#   '+001 100 594-5038',
#   'Father_And_Sons_S.A_010@outlook.com',
#   20120318,
#   10001,
#   'NY'),
#  ('10001-008',
#   'Father And Sons Company 039',
#   'D',
#   201,
#   '+001 100 204-5533',
#   'Father_And_Sons_Company_039@outlook.com',
#   20110402,
#   10001,
#   'NY'),
#  ('10001-009',
#   'Father And Sons Solutions 043',
#   'D',
#   201,
#   '+001 100 294-3609',
#   'Father_And_Sons_Solutions_043@outlook.com',
#   20140619,
#   10001,
#   'NY'),
#  ('10001-010',
#   'Digital Corporation 045',
#   'C',
#   201,
#   '+001 100 346-5709',
#   'Digital_Corporation_045@outlook.com',
#   20080618,
#   10001,
#   'NY'),
#  ('10001-011',
#   'Computer Corporation 064',
#   'D',
#   201,
#   '+001 100 999-3608',
#   'Computer_Corporation_064@gmail.com.br',
#   20200215,
#   10001,
#   'NY'),
#  ('10001-012',
#   'Genius Company 001',
#   'D',
#   201,
#   '+001 100 688-4197',
#   'Genius_Company_001@outlook.com',
#   20010501,
#   10001,
#   'NY'),
#  ('10001-013',
#   'Alpha S.A 090',
#   'D',
#   201,
#   '+001 100 353-5891',
#   'Alpha_S.A_090@outlook.com',
#   20140723,
#   10001,
#   'NY'),
#  ('10001-014',
#   'Beta Corporation 068',
#   'C',
#   201,
#   '+001 100 750-8138',
#   'Beta_Corporation_068@gmail.com.br',
#   20140708,
#   10001,
#   'NY'),
#  ('10001-015',
#   'Alpha Store 044',
#   'D',
#   201,
#   '+001 100 357-2432',
#   'Alpha_Store_044@gmail.com.br',
#   20040720,
#   10001,
#   'NY'),
#  ('10001-016',
#   'Digital S.A 075',
#   'D',
#   201,
#   '+001 100 148-7787',
#   'Digital_S.A_075@outlook.com',
#   20100925,
#   10001,
#   'NY'),
#  ('10001-017',
#   'Technologic Store 096',
#   'A',
#   201,
#   '+001 100 800-2117',
#   'Technologic_Store_096@outlook.com',
#   20020307,
#   10001,
#   'NY'),
#  ('10001-018',
#   'Digital World 078',
#   'C',
#   201,
#   '+001 100 482-4237',
#   'Digital_World_078@outlook.com',
#   20130124,
#   10001,
#   'NY'),
#  ('10001-019',
#   'Alpha Corporation 095',
#   'C',
#   201,
#   '+001 100 190-7562',
#   'Alpha_Corporation_095@outlook.com',
#   20070827,
#   10001,
#   'NY'),
#  ('10001-020',
#   'Essential Company 070',
#   'D',
#   201,
#   '+001 100 446-9263',
#   'Essential_Company_070@outlook.com',
#   20201030,
#   10001,
#   'NY'),
#  ('10001-021',
#   'Beta Store 088',
#   'D',
#   201,
#   '+001 100 626-6294',
#   'Beta_Store_088@outlook.com',
#   20040215,
#   10001,
#   'NY'),
#  ('10001-022',
#   'High Tech Techno 056',
#   'D',
#   201,
#   '+001 100 431-7284',
#   'High_Tech_Techno_056@outlook.com',
#   20050206,
#   10001,
#   'NY'),
#  ('10001-023',
#   'High Tech Tech 068',
#   'D',
#   201,
#   '+001 100 898-1686',
#   'High_Tech_Tech_068@outlook.com',
#   20040726,
#   10001,
#   'NY'),
#  ('10001-024',
#   'Beta Company 090',
#   'D',
#   201,
#   '+001 100 626-4747',
#   'Beta_Company_090@outlook.com',
#   20150306,
#   10001,
#   'NY'),
#  ('10001-025',
#   'High Tech Company 085',
#   'C',
#   201,
#   '+001 100 909-1294',
#   'High_Tech_Company_085@outlook.com',
#   20010909,
#   10001,
#   'NY'),
#  ('10001-026',
#   'Beta Store 045',
#   'D',
#   201,
#   '+001 100 853-2405',
#   'Beta_Store_045@gmail.com.br',
#   20191028,
#   10001,
#   'NY'),
#  ('10001-027',
#   'Beta Corporation 011',
#   'C',
#   201,
#   '+001 100 700-6521',
#   'Beta_Corporation_011@outlook.com',
#   20100414,
#   10001,
#   'NY'),
#  ('10001-028',
#   'Digital Electronics 063',
#   'D',
#   201,
#   '+001 100 276-5989',
#   'Digital_Electronics_063@outlook.com',
#   20130502,
#   10001,
#   'NY'),
#  ('10001-029',
#   'Technologic Inc. 081',
#   'D',
#   201,
#   '+001 100 659-6809',
#   'Technologic_Inc._081@gmail.com.br',
#   20130427,
#   10001,
#   'NY'),
#  ('10001-030',
#   'Father And Sons Store 006',
#   'C',
#   201,
#   '+001 100 835-2408',
#   'Father_And_Sons_Store_006@outlook.com',
#   20160720,
#   10001,
#   'NY'),
#  ('10001-031',
#   'Beta World 011',
#   'D',
#   201,
#   '+001 100 740-3923',
#   'Beta_World_011@outlook.com',
#   20030404,
#   10001,
#   'NY'),
#  ('10001-032',
#   'High Tech World 038',
#   'D',
#   201,
#   '+001 100 860-3560',
#   'High_Tech_World_038@outlook.com',
#   20170225,
#   10001,
#   'NY'),
#  ('10001-033',
#   'Digital World 099',
#   'C',
#   201,
#   '+001 100 577-2887',
#   'Digital_World_099@outlook.com',
#   20121119,
#   10001,
#   'NY'),
#  ('10001-034',
#   'Technologic Electronics 063',
#   'D',
#   201,
#   '+001 100 409-2334',
#   'Technologic_Electronics_063@outlook.com',
#   20171009,
#   10001,
#   'NY'),
#  ('10001-035',
#   'Computer Electronics 005',
#   'B',
#   201,
#   '+001 100 114-2484',
#   'Computer_Electronics_005@gmail.com.br',
#   20040825,
#   10001,
#   'NY'),
#  ('10001-036',
#   'Alpha S.A 047',
#   'D',
#   201,
#   '+001 100 892-7776',
#   'Alpha_S.A_047@outlook.com',
#   20171101,
#   10001,
#   'NY'),
#  ('73301-001',
#   'Technologic Electronics 081',
#   'D',
#   202,
#   '+001 733 906-7442',
#   'Technologic_Electronics_081@outlook.com',
#   20200602,
#   73301,
#   'TX'),
#  ('73301-002',
#   'Technologic Electronics 030',
#   'C',
#   202,
#   '+001 733 447-8701',
#   'Technologic_Electronics_030@outlook.com',
#   20090713,
#   73301,
#   'TX'),
#  ('73301-003',
#   'Computer Electronics 002',
#   'D',
#   202,
#   '+001 733 708-3585',
#   'Computer_Electronics_002@outlook.com',
#   20021212,
#   73301,
#   'TX'),
#  ('73301-004',
#   'Technologic World 063',
#   'D',
#   202,
#   '+001 733 346-8795',
#   'Technologic_World_063@outlook.com',
#   20180929,
#   73301,
#   'TX'),
#  ('73301-005',
#   'Father And Sons S.A 054',
#   'D',
#   202,
#   '+001 733 861-9109',
#   'Father_And_Sons_S.A_054@outlook.com',
#   20100623,
#   73301,
#   'TX'),
#  ('73301-006',
#   'Digital Company 003',
#   'D',
#   202,
#   '+001 733 763-9015',
#   'Digital_Company_003@outlook.com',
#   20000419,
#   73301,
#   'TX'),
#  ('73301-007',
#   'Alpha Inc. 006',
#   'D',
#   202,
#   '+001 733 422-3138',
#   'Alpha_Inc._006@outlook.com',
#   20190525,
#   73301,
#   'TX'),
#  ('73301-008',
#   'Genius Inc. 036',
#   'B',
#   202,
#   '+001 733 730-1632',
#   'Genius_Inc._036@outlook.com',
#   20191025,
#   73301,
#   'TX'),
#  ('73301-009',
#   'Digital Store 067',
#   'C',
#   202,
#   '+001 733 433-7155',
#   'Digital_Store_067@outlook.com',
#   20090605,
#   73301,
#   'TX'),
#  ('73301-010',
#   'High Tech Solutions 024',
#   'B',
#   202,
#   '+001 733 340-5698',
#   'High_Tech_Solutions_024@outlook.com',
#   20090904,
#   73301,
#   'TX'),
#  ('73301-011',
#   'Father And Sons S.A 029',
#   'B',
#   202,
#   '+001 733 830-5885',
#   'Father_And_Sons_S.A_029@gmail.com.br',
#   20190116,
#   73301,
#   'TX'),
#  ('73301-012',
#   'Computer World 028',
#   'D',
#   202,
#   '+001 733 797-6530',
#   'Computer_World_028@outlook.com',
#   20071205,
#   73301,
#   'TX'),
#  ('73301-013',
#   'Technologic World 100',
#   'C',
#   202,
#   '+001 733 464-2490',
#   'Technologic_World_100@outlook.com',
#   20020714,
#   73301,
#   'TX'),
#  ('73301-014',
#   'Technologic Store 074',
#   'D',
#   202,
#   '+001 733 594-4239',
#   'Technologic_Store_074@gmail.com.br',
#   20140708,
#   73301,
#   'TX'),
#  ('73301-015',
#   'Beta Inc. 060',
#   'D',
#   202,
#   '+001 733 253-8290',
#   'Beta_Inc._060@outlook.com',
#   20070420,
#   73301,
#   'TX'),
#  ('73301-016',
#   'Genius Inc. 023',
#   'B',
#   202,
#   '+001 733 335-4349',
#   'Genius_Inc._023@outlook.com',
#   20090112,
#   73301,
#   'TX'),
#  ('73301-017',
#   'Genius Solutions 012',
#   'D',
#   202,
#   '+001 733 709-7618',
#   'Genius_Solutions_012@outlook.com',
#   20150727,
#   73301,
#   'TX'),
#  ('73301-018',
#   'High Tech S.A 043',
#   'B',
#   202,
#   '+001 733 399-6262',
#   'High_Tech_S.A_043@outlook.com',
#   20070125,
#   73301,
#   'TX'),
#  ('73301-019',
#   'Digital Techno 050',
#   'B',
#   202,
#   '+001 733 721-3035',
#   'Digital_Techno_050@outlook.com',
#   20080226,
#   73301,
#   'TX'),
#  ('73301-020',
#   'Technologic World 084',
#   'C',
#   202,
#   '+001 733 109-5458',
#   'Technologic_World_084@gmail.com.br',
#   20181028,
#   73301,
#   'TX'),
#  ('73301-021',
#   'Father And Sons Tech 034',
#   'A',
#   202,
#   '+001 733 416-2115',
#   'Father_And_Sons_Tech_034@outlook.com',
#   20001117,
#   73301,
#   'TX'),
#  ('73301-022',
#   'Essential Inc. 036',
#   'D',
#   202,
#   '+001 733 200-6709',
#   'Essential_Inc._036@outlook.com',
#   20200426,
#   73301,
#   'TX'),
#  ('73301-023',
#   'Technologic Corporation 045',
#   'D',
#   202,
#   '+001 733 515-3717',
#   'Technologic_Corporation_045@gmail.com.br',
#   20000301,
#   73301,
#   'TX'),
#  ('73301-024',
#   'Essential Techno 059',
#   'D',
#   202,
#   '+001 733 922-5140',
#   'Essential_Techno_059@outlook.com',
#   20020602,
#   73301,
#   'TX'),
#  ('73301-025',
#   'Digital Techno 076',
#   'A',
#   202,
#   '+001 733 767-1380',
#   'Digital_Techno_076@outlook.com',
#   20160614,
#   73301,
#   'TX'),
#  ('73301-026',
#   'Genius Corporation 022',
#   'B',
#   202,
#   '+001 733 878-8434',
#   'Genius_Corporation_022@outlook.com',
#   20020402,
#   73301,
#   'TX'),
#  ('73301-027',
#   'High Tech S.A 005',
#   'B',
#   202,
#   '+001 733 536-3339',
#   'High_Tech_S.A_005@outlook.com',
#   20061007,
#   73301,
#   'TX'),
#  ('73301-028',
#   'Essential World 091',
#   'D',
#   202,
#   '+001 733 183-7555',
#   'Essential_World_091@outlook.com',
#   20040403,
#   73301,
#   'TX'),
#  ('73301-029',
#   'Technologic Electronics 068',
#   'C',
#   202,
#   '+001 733 898-7687',
#   'Technologic_Electronics_068@outlook.com',
#   20191125,
#   73301,
#   'TX'),
#  ('73301-030',
#   'Technologic Tech 043',
#   'D',
#   202,
#   '+001 733 656-3244',
#   'Technologic_Tech_043@outlook.com',
#   20181111,
#   73301,
#   'TX'),
#  ('73301-031',
#   'Father And Sons Inc. 033',
#   'C',
#   202,
#   '+001 733 443-3988',
#   'Father_And_Sons_Inc._033@outlook.com',
#   20000518,
#   73301,
#   'TX'),
#  ('73301-032',
#   'Alpha World 075',
#   'D',
#   202,
#   '+001 733 898-1774',
#   'Alpha_World_075@outlook.com',
#   20120521,
#   73301,
#   'TX'),
#  ('73301-033',
#   'Genius Store 012',
#   'D',
#   202,
#   '+001 733 345-9824',
#   'Genius_Store_012@outlook.com',
#   20011228,
#   73301,
#   'TX'),
#  ('73301-034',
#   'Alpha Company 044',
#   'D',
#   202,
#   '+001 733 588-2227',
#   'Alpha_Company_044@outlook.com',
#   20091022,
#   73301,
#   'TX'),
#  ('73301-035',
#   'Essential Solutions 053',
#   'B',
#   202,
#   '+001 733 737-2723',
#   'Essential_Solutions_053@gmail.com.br',
#   20020821,
#   73301,
#   'TX'),
#  ('73301-036',
#   'Digital World 088',
#   'A',
#   202,
#   '+001 733 929-7740',
#   'Digital_World_088@outlook.com',
#   20040324,
#   73301,
#   'TX'),
#  ('73301-037',
#   'Essential Corporation 044',
#   'B',
#   202,
#   '+001 733 685-7218',
#   'Essential_Corporation_044@outlook.com',
#   20051209,
#   73301,
#   'TX'),
#  ('73301-038',
#   'Computer Corporation 061',
#   'D',
#   202,
#   '+001 733 385-5720',
#   'Computer_Corporation_061@outlook.com',
#   20061218,
#   73301,
#   'TX'),
#  ('73301-039',
#   'Alpha Techno 078',
#   'D',
#   202,
#   '+001 733 173-6870',
#   'Alpha_Techno_078@outlook.com',
#   20160315,
#   73301,
#   'TX'),
#  ('73301-040',
#   'Essential Tech 085',
#   'C',
#   202,
#   '+001 733 291-4907',
#   'Essential_Tech_085@gmail.com.br',
#   20190905,
#   73301,
#   'TX'),
#  ('73301-041',
#   'Alpha Inc. 038',
#   'C',
#   202,
#   '+001 733 593-8313',
#   'Alpha_Inc._038@gmail.com.br',
#   20110503,
#   73301,
#   'TX'),
#  ('73301-042',
#   'Essential Electronics 049',
#   'C',
#   202,
#   '+001 733 478-5231',
#   'Essential_Electronics_049@gmail.com.br',
#   20030302,
#   73301,
#   'TX'),
#  ('73301-043',
#   'Computer Solutions 029',
#   'C',
#   202,
#   '+001 733 725-5088',
#   'Computer_Solutions_029@outlook.com',
#   20120411,
#   73301,
#   'TX'),
#  ('73301-044',
#   'Beta Company 042',
#   'D',
#   202,
#   '+001 733 827-9939',
#   'Beta_Company_042@outlook.com',
#   20040830,
#   73301,
#   'TX'),
#  ('73301-045',
#   'Technologic Solutions 030',
#   'C',
#   202,
#   '+001 733 559-1178',
#   'Technologic_Solutions_030@outlook.com',
#   20030830,
#   73301,
#   'TX'),
#  ('73301-046',
#   'High Tech Tech 085',
#   'B',
#   202,
#   '+001 733 996-6631',
#   'High_Tech_Tech_085@gmail.com.br',
#   20011016,
#   73301,
#   'TX'),
#  ('73301-047',
#   'Digital Store 020',
#   'D',
#   202,
#   '+001 733 660-9424',
#   'Digital_Store_020@outlook.com',
#   20120806,
#   73301,
#   'TX'),
#  ('73301-048',
#   'Beta S.A 068',
#   'D',
#   202,
#   '+001 733 779-9661',
#   'Beta_S.A_068@outlook.com',
#   20110207,
#   73301,
#   'TX'),
#  ('73301-049',
#   'Digital Techno 087',
#   'A',
#   202,
#   '+001 733 604-2523',
#   'Digital_Techno_087@gmail.com.br',
#   20090503,
#   73301,
#   'TX'),
#  ('73301-050',
#   'Father And Sons Corporation 082',
#   'C',
#   202,
#   '+001 733 453-4470',
#   'Father_And_Sons_Corporation_082@outlook.com',
#   20100904,
#   73301,
#   'TX'),
#  ('73301-051',
#   'Genius Tech 084',
#   'B',
#   202,
#   '+001 733 202-5401',
#   'Genius_Tech_084@outlook.com',
#   20110527,
#   73301,
#   'TX'),
#  ('73301-052',
#   'Alpha Company 037',
#   'D',
#   202,
#   '+001 733 400-9553',
#   'Alpha_Company_037@outlook.com',
#   20050927,
#   73301,
#   'TX'),
#  ('73301-053',
#   'Genius Store 055',
#   'C',
#   202,
#   '+001 733 461-2677',
#   'Genius_Store_055@gmail.com.br',
#   20151212,
#   73301,
#   'TX'),
#  ('73301-054',
#   'Genius Company 049',
#   'D',
#   202,
#   '+001 733 214-4281',
#   'Genius_Company_049@outlook.com',
#   20120813,
#   73301,
#   'TX'),
#  ('73301-055',
#   'Digital Store 007',
#   'D',
#   202,
#   '+001 733 703-8749',
#   'Digital_Store_007@outlook.com',
#   20180328,
#   73301,
#   'TX'),
#  ('73301-056',
#   'Alpha Company 065',
#   'C',
#   202,
#   '+001 733 826-8605',
#   'Alpha_Company_065@outlook.com',
#   20160814,
#   73301,
#   'TX'),
#  ('73301-057',
#   'Genius S.A 089',
#   'D',
#   202,
#   '+001 733 307-4902',
#   'Genius_S.A_089@outlook.com',
#   20141228,
#   73301,
#   'TX'),
#  ('73301-058',
#   'Technologic S.A 072',
#   'C',
#   202,
#   '+001 733 662-3951',
#   'Technologic_S.A_072@gmail.com.br',
#   20170527,
#   73301,
#   'TX'),
#  ('73301-059',
#   'Alpha Techno 000',
#   'D',
#   202,
#   '+001 733 864-2956',
#   'Alpha_Techno_000@gmail.com.br',
#   20160710,
#   73301,
#   'TX'),
#  ('73301-060',
#   'Technologic Techno 054',
#   'A',
#   202,
#   '+001 733 241-1165',
#   'Technologic_Techno_054@outlook.com',
#   20001109,
#   73301,
#   'TX'),
#  ('73301-061',
#   'Father And Sons Tech 031',
#   'D',
#   202,
#   '+001 733 979-9467',
#   'Father_And_Sons_Tech_031@outlook.com',
#   20200611,
#   73301,
#   'TX'),
#  ('73301-062',
#   'High Tech Tech 057',
#   'D',
#   202,
#   '+001 733 515-2287',
#   'High_Tech_Tech_057@outlook.com',
#   20101124,
#   73301,
#   'TX'),
#  ('73301-063',
#   'Father And Sons Corporation 078',
#   'C',
#   202,
#   '+001 733 474-9758',
#   'Father_And_Sons_Corporation_078@outlook.com',
#   20020103,
#   73301,
#   'TX'),
#  ('73301-064',
#   'Technologic Company 055',
#   'D',
#   202,
#   '+001 733 784-7563',
#   'Technologic_Company_055@outlook.com',
#   20141004,
#   73301,
#   'TX'),
#  ('73301-065',
#   'Computer Solutions 043',
#   'C',
#   202,
#   '+001 733 651-2378',
#   'Computer_Solutions_043@outlook.com',
#   20120605,
#   73301,
#   'TX'),
#  ('73301-066',
#   'Essential S.A 061',
#   'D',
#   202,
#   '+001 733 755-1750',
#   'Essential_S.A_061@gmail.com.br',
#   20190627,
#   73301,
#   'TX'),
#  ('73301-067',
#   'Essential S.A 042',
#   'C',
#   202,
#   '+001 733 581-9178',
#   'Essential_S.A_042@outlook.com',
#   20080803,
#   73301,
#   'TX'),
#  ('73301-068',
#   'Alpha World 065',
#   'A',
#   202,
#   '+001 733 394-5108',
#   'Alpha_World_065@outlook.com',
#   20180114,
#   73301,
#   'TX'),
#  ('73301-069',
#   'Technologic Tech 055',
#   'B',
#   202,
#   '+001 733 286-6314',
#   'Technologic_Tech_055@outlook.com',
#   20180830,
#   73301,
#   'TX'),
#  ('73301-070',
#   'Father And Sons Company 003',
#   'D',
#   202,
#   '+001 733 980-4808',
#   'Father_And_Sons_Company_003@outlook.com',
#   20100618,
#   73301,
#   'TX'),
#  ('73301-071',
#   'Technologic Store 067',
#   'D',
#   202,
#   '+001 733 854-6333',
#   'Technologic_Store_067@gmail.com.br',
#   20110316,
#   73301,
#   'TX'),
#  ('73301-072',
#   'Alpha Electronics 092',
#   'C',
#   202,
#   '+001 733 160-7760',
#   'Alpha_Electronics_092@outlook.com',
#   20000530,
#   73301,
#   'TX'),
#  ('73301-073',
#   'Alpha Company 075',
#   'D',
#   202,
#   '+001 733 253-5091',
#   'Alpha_Company_075@outlook.com',
#   20181101,
#   73301,
#   'TX'),
#  ('73301-074',
#   'High Tech Corporation 061',
#   'C',
#   202,
#   '+001 733 233-5267',
#   'High_Tech_Corporation_061@outlook.com',
#   20130714,
#   73301,
#   'TX'),
#  ('73301-075',
#   'Alpha Corporation 043',
#   'B',
#   202,
#   '+001 733 745-7259',
#   'Alpha_Corporation_043@outlook.com',
#   20050628,
#   73301,
#   'TX'),
#  ('73301-076',
#   'Technologic Techno 084',
#   'C',
#   202,
#   '+001 733 639-4058',
#   'Technologic_Techno_084@outlook.com',
#   20081110,
#   73301,
#   'TX'),
#  ('73301-077',
#   'Genius Electronics 064',
#   'B',
#   202,
#   '+001 733 657-4024',
#   'Genius_Electronics_064@outlook.com',
#   20080307,
#   73301,
#   'TX'),
#  ('73301-078',
#   'Digital Inc. 001',
#   'B',
#   202,
#   '+001 733 895-1518',
#   'Digital_Inc._001@outlook.com',
#   20080803,
#   73301,
#   'TX'),
#  ('73301-079',
#   'Computer Store 049',
#   'A',
#   202,
#   '+001 733 220-9311',
#   'Computer_Store_049@gmail.com.br',
#   20040711,
#   73301,
#   'TX'),
#  ('73301-080',
#   'Technologic Store 081',
#   'D',
#   202,
#   '+001 733 105-6147',
#   'Technologic_Store_081@outlook.com',
#   20091222,
#   73301,
#   'TX'),
#  ('73301-081',
#   'High Tech S.A 066',
#   'D',
#   202,
#   '+001 733 514-8127',
#   'High_Tech_S.A_066@outlook.com',
#   20050308,
#   73301,
#   'TX'),
#  ('73301-082',
#   'Alpha Electronics 080',
#   'A',
#   202,
#   '+001 733 431-6221',
#   'Alpha_Electronics_080@outlook.com',
#   20080813,
#   73301,
#   'TX'),
#  ('73301-083',
#   'Digital Store 050',
#   'A',
#   202,
#   '+001 733 372-2027',
#   'Digital_Store_050@outlook.com',
#   20000125,
#   73301,
#   'TX'),
#  ('73301-084',
#   'Beta Electronics 052',
#   'D',
#   202,
#   '+001 733 129-3013',
#   'Beta_Electronics_052@gmail.com.br',
#   20040425,
#   73301,
#   'TX'),
#  ('73301-085',
#   'Digital World 092',
#   'B',
#   202,
#   '+001 733 522-5539',
#   'Digital_World_092@gmail.com.br',
#   20060419,
#   73301,
#   'TX'),
#  ('73301-086',
#   'Genius S.A 020',
#   'C',
#   202,
#   '+001 733 880-4582',
#   'Genius_S.A_020@outlook.com',
#   20010215,
#   73301,
#   'TX'),
#  ('73301-087',
#   'Beta World 063',
#   'C',
#   202,
#   '+001 733 855-9193',
#   'Beta_World_063@outlook.com',
#   20070221,
#   73301,
#   'TX'),
#  ('73301-088',
#   'Technologic Solutions 058',
#   'B',
#   202,
#   '+001 733 194-3581',
#   'Technologic_Solutions_058@gmail.com.br',
#   20160921,
#   73301,
#   'TX'),
#  ('73301-089',
#   'Computer Tech 048',
#   'C',
#   202,
#   '+001 733 690-4407',
#   'Computer_Tech_048@gmail.com.br',
#   20050323,
#   73301,
#   'TX'),
#  ('73301-090',
#   'Digital World 071',
#   'D',
#   202,
#   '+001 733 974-5077',
#   'Digital_World_071@outlook.com',
#   20171130,
#   73301,
#   'TX'),
#  ('73301-091',
#   'Technologic Tech 072',
#   'B',
#   202,
#   '+001 733 895-2970',
#   'Technologic_Tech_072@gmail.com.br',
#   20191224,
#   73301,
#   'TX'),
#  ('73301-092',
#   'Computer Solutions 054',
#   'D',
#   202,
#   '+001 733 421-6561',
#   'Computer_Solutions_054@gmail.com.br',
#   20040517,
#   73301,
#   'TX'),
#  ('73301-093',
#   'Computer Techno 010',
#   'C',
#   202,
#   '+001 733 494-5739',
#   'Computer_Techno_010@outlook.com',
#   20000224,
#   73301,
#   'TX'),
#  ('73301-094',
#   'Alpha Inc. 077',
#   'D',
#   202,
#   '+001 733 350-7096',
#   'Alpha_Inc._077@outlook.com',
#   20020525,
#   73301,
#   'TX'),
#  ('73301-095',
#   'Technologic World 006',
#   'D',
#   202,
#   '+001 733 506-6513',
#   'Technologic_World_006@outlook.com',
#   20070328,
#   73301,
#   'TX'),
#  ('73301-096',
#   'Digital Store 009',
#   'B',
#   202,
#   '+001 733 639-8479',
#   'Digital_Store_009@gmail.com.br',
#   20130813,
#   73301,
#   'TX'),
#  ('73301-097',
#   'High Tech Company 012',
#   'C',
#   202,
#   '+001 733 341-3864',
#   'High_Tech_Company_012@gmail.com.br',
#   20200110,
#   73301,
#   'TX'),
#  ('73301-098',
#   'Essential S.A 095',
#   'D',
#   202,
#   '+001 733 541-7196',
#   'Essential_S.A_095@outlook.com',
#   20050915,
#   73301,
#   'TX'),
#  ('90001-001',
#   'Alpha Store 078',
#   'C',
#   203,
#   '+001 900 308-3499',
#   'Alpha_Store_078@outlook.com',
#   20020403,
#   90001,
#   'CA'),
#  ('90001-002',
#   'Father And Sons Electronics 083',
#   'C',
#   203,
#   '+001 900 362-9942',
#   'Father_And_Sons_Electronics_083@outlook.com',
#   20101130,
#   90001,
#   'CA'),
#  ('90001-003',
#   'Digital Solutions 067',
#   'A',
#   203,
#   '+001 900 570-7068',
#   'Digital_Solutions_067@gmail.com.br',
#   20071119,
#   90001,
#   'CA'),
#  ('90001-004',
#   'High Tech Solutions 001',
#   'B',
#   203,
#   '+001 900 195-6580',
#   'High_Tech_Solutions_001@gmail.com.br',
#   20140625,
#   90001,
#   'CA'),
#  ('90001-005',
#   'Technologic Electronics 029',
#   'C',
#   203,
#   '+001 900 773-2446',
#   'Technologic_Electronics_029@outlook.com',
#   20140426,
#   90001,
#   'CA'),
#  ('90001-006',
#   'Genius Corporation 011',
#   'C',
#   203,
#   '+001 900 397-1607',
#   'Genius_Corporation_011@outlook.com',
#   20000408,
#   90001,
#   'CA'),
#  ('90001-007',
#   'Alpha World 081',
#   'B',
#   203,
#   '+001 900 213-8529',
#   'Alpha_World_081@gmail.com.br',
#   20130111,
#   90001,
#   'CA'),
#  ('90001-008',
#   'Computer Store 005',
#   'C',
#   203,
#   '+001 900 811-3827',
#   'Computer_Store_005@outlook.com',
#   20080309,
#   90001,
#   'CA'),
#  ('90001-009',
#   'Technologic Electronics 097',
#   'C',
#   203,
#   '+001 900 728-2974',
#   'Technologic_Electronics_097@outlook.com',
#   20020614,
#   90001,
#   'CA'),
#  ('90001-010',
#   'Essential Tech 098',
#   'A',
#   203,
#   '+001 900 953-9623',
#   'Essential_Tech_098@outlook.com',
#   20040814,
#   90001,
#   'CA'),
#  ('90001-011',
#   'Father And Sons S.A 026',
#   'D',
#   203,
#   '+001 900 823-1938',
#   'Father_And_Sons_S.A_026@outlook.com',
#   20130626,
#   90001,
#   'CA'),
#  ('90001-012',
#   'Alpha Inc. 023',
#   'C',
#   203,
#   '+001 900 595-8571',
#   'Alpha_Inc._023@gmail.com.br',
#   20080517,
#   90001,
#   'CA'),
#  ('90001-013',
#   'Father And Sons S.A 073',
#   'C',
#   203,
#   '+001 900 541-3764',
#   'Father_And_Sons_S.A_073@outlook.com',
#   20171011,
#   90001,
#   'CA'),
#  ('90001-014',
#   'High Tech Corporation 017',
#   'D',
#   203,
#   '+001 900 979-8094',
#   'High_Tech_Corporation_017@outlook.com',
#   20030210,
#   90001,
#   'CA'),
#  ('90001-015',
#   'Beta Store 085',
#   'D',
#   203,
#   '+001 900 422-3571',
#   'Beta_Store_085@outlook.com',
#   20170111,
#   90001,
#   'CA'),
#  ('90001-016',
#   'Genius Solutions 057',
#   'D',
#   203,
#   '+001 900 712-8249',
#   'Genius_Solutions_057@outlook.com',
#   20190822,
#   90001,
#   'CA'),
#  ('90001-017',
#   'Father And Sons World 020',
#   'B',
#   203,
#   '+001 900 962-9456',
#   'Father_And_Sons_World_020@outlook.com',
#   20190615,
#   90001,
#   'CA'),
#  ('90001-018',
#   'Computer S.A 070',
#   'B',
#   203,
#   '+001 900 800-6419',
#   'Computer_S.A_070@outlook.com',
#   20100626,
#   90001,
#   'CA'),
#  ('90001-019',
#   'Alpha Corporation 083',
#   'B',
#   203,
#   '+001 900 258-1821',
#   'Alpha_Corporation_083@outlook.com',
#   20121110,
#   90001,
#   'CA'),
#  ('90001-020',
#   'Technologic Solutions 033',
#   'D',
#   203,
#   '+001 900 877-4868',
#   'Technologic_Solutions_033@outlook.com',
#   20010107,
#   90001,
#   'CA'),
#  ('90001-021',
#   'Beta Corporation 082',
#   'C',
#   203,
#   '+001 900 439-4803',
#   'Beta_Corporation_082@gmail.com.br',
#   20170430,
#   90001,
#   'CA'),
#  ('90001-022',
#   'Beta Corporation 047',
#   'D',
#   203,
#   '+001 900 273-4055',
#   'Beta_Corporation_047@outlook.com',
#   20170417,
#   90001,
#   'CA'),
#  ('90001-023',
#   'Technologic Company 037',
#   'C',
#   203,
#   '+001 900 418-6374',
#   'Technologic_Company_037@gmail.com.br',
#   20070212,
#   90001,
#   'CA'),
#  ('90001-024',
#   'Technologic Inc. 091',
#   'C',
#   203,
#   '+001 900 869-9879',
#   'Technologic_Inc._091@outlook.com',
#   20150202,
#   90001,
#   'CA'),
#  ('90001-025',
#   'Father And Sons Techno 027',
#   'D',
#   203,
#   '+001 900 358-4618',
#   'Father_And_Sons_Techno_027@outlook.com',
#   20130304,
#   90001,
#   'CA'),
#  ('90001-026',
#   'Father And Sons Inc. 045',
#   'C',
#   203,
#   '+001 900 445-5630',
#   'Father_And_Sons_Inc._045@outlook.com',
#   20030519,
#   90001,
#   'CA'),
#  ('90001-027',
#   'Digital Corporation 056',
#   'D',
#   203,
#   '+001 900 191-8157',
#   'Digital_Corporation_056@outlook.com',
#   20100102,
#   90001,
#   'CA'),
#  ('90001-028',
#   'Beta Corporation 076',
#   'D',
#   203,
#   '+001 900 164-8435',
#   'Beta_Corporation_076@outlook.com',
#   20130530,
#   90001,
#   'CA'),
#  ('90001-029',
#   'Beta S.A 092',
#   'D',
#   203,
#   '+001 900 727-5895',
#   'Beta_S.A_092@outlook.com',
#   20160521,
#   90001,
#   'CA'),
#  ('90001-030',
#   'Genius Electronics 080',
#   'D',
#   203,
#   '+001 900 975-1270',
#   'Genius_Electronics_080@gmail.com.br',
#   20141010,
#   90001,
#   'CA'),
#  ('90001-031',
#   'Digital World 093',
#   'D',
#   203,
#   '+001 900 581-9799',
#   'Digital_World_093@outlook.com',
#   20161109,
#   90001,
#   'CA'),
#  ('90001-032',
#   'Alpha World 040',
#   'D',
#   203,
#   '+001 900 675-3977',
#   'Alpha_World_040@outlook.com',
#   20011106,
#   90001,
#   'CA'),
#  ('90001-033',
#   'Digital Corporation 097',
#   'B',
#   203,
#   '+001 900 594-2412',
#   'Digital_Corporation_097@outlook.com',
#   20121019,
#   90001,
#   'CA'),
#  ('90001-034',
#   'Technologic Electronics 005',
#   'D',
#   203,
#   '+001 900 624-5695',
#   'Technologic_Electronics_005@gmail.com.br',
#   20040323,
#   90001,
#   'CA'),
#  ('90001-035',
#   'High Tech Company 047',
#   'D',
#   203,
#   '+001 900 325-6015',
#   'High_Tech_Company_047@outlook.com',
#   20010726,
#   90001,
#   'CA'),
#  ('90001-036',
#   'Genius Inc. 047',
#   'C',
#   203,
#   '+001 900 420-1547',
#   'Genius_Inc._047@outlook.com',
#   20050813,
#   90001,
#   'CA'),
#  ('90001-037',
#   'Essential World 006',
#   'D',
#   203,
#   '+001 900 225-6822',
#   'Essential_World_006@outlook.com',
#   20061013,
#   90001,
#   'CA'),
#  ('90001-038',
#   'Digital Electronics 038',
#   'B',
#   203,
#   '+001 900 285-7094',
#   'Digital_Electronics_038@gmail.com.br',
#   20060103,
#   90001,
#   'CA'),
#  ('90001-039',
#   'Essential Tech 058',
#   'D',
#   203,
#   '+001 900 112-3503',
#   'Essential_Tech_058@outlook.com',
#   20140218,
#   90001,
#   'CA'),
#  ('90001-040',
#   'Beta Inc. 035',
#   'D',
#   203,
#   '+001 900 588-4445',
#   'Beta_Inc._035@outlook.com',
#   20100214,
#   90001,
#   'CA'),
#  ('90001-041',
#   'Alpha Company 092',
#   'D',
#   203,
#   '+001 900 875-3459',
#   'Alpha_Company_092@outlook.com',
#   20110622,
#   90001,
#   'CA'),
#  ('90001-042',
#   'High Tech Solutions 095',
#   'D',
#   203,
#   '+001 900 765-3466',
#   'High_Tech_Solutions_095@outlook.com',
#   20070310,
#   90001,
#   'CA'),
#  ('90001-043',
#   'Father And Sons Tech 065',
#   'D',
#   203,
#   '+001 900 738-4543',
#   'Father_And_Sons_Tech_065@outlook.com',
#   20021004,
#   90001,
#   'CA'),
#  ('90001-044',
#   'Beta Corporation 097',
#   'D',
#   203,
#   '+001 900 924-9406',
#   'Beta_Corporation_097@gmail.com.br',
#   20070506,
#   90001,
#   'CA'),
#  ('90001-045',
#   'Technologic World 030',
#   'C',
#   203,
#   '+001 900 923-1070',
#   'Technologic_World_030@outlook.com',
#   20150921,
#   90001,
#   'CA'),
#  ('90001-046',
#   'Alpha Tech 098',
#   'C',
#   203,
#   '+001 900 349-9758',
#   'Alpha_Tech_098@outlook.com',
#   20051008,
#   90001,
#   'CA'),
#  ('90001-047',
#   'Alpha Company 049',
#   'D',
#   203,
#   '+001 900 407-2651',
#   'Alpha_Company_049@outlook.com',
#   20050119,
#   90001,
#   'CA'),
#  ('90001-048',
#   'Alpha World 059',
#   'C',
#   203,
#   '+001 900 127-6039',
#   'Alpha_World_059@outlook.com',
#   20050624,
#   90001,
#   'CA'),
#  ('90001-049',
#   'Alpha Techno 055',
#   'B',
#   203,
#   '+001 900 323-6644',
#   'Alpha_Techno_055@outlook.com',
#   20200516,
#   90001,
#   'CA'),
#  ('90001-050',
#   'Alpha Techno 050',
#   'D',
#   203,
#   '+001 900 865-7263',
#   'Alpha_Techno_050@outlook.com',
#   20070214,
#   90001,
#   'CA'),
#  ('90001-051',
#   'Genius Company 042',
#   'D',
#   203,
#   '+001 900 229-5710',
#   'Genius_Company_042@outlook.com',
#   20041017,
#   90001,
#   'CA'),
#  ('90001-052',
#   'Beta Tech 078',
#   'C',
#   203,
#   '+001 900 434-8632',
#   'Beta_Tech_078@outlook.com',
#   20111217,
#   90001,
#   'CA'),
#  ('90001-053',
#   'Alpha World 000',
#   'C',
#   203,
#   '+001 900 543-2960',
#   'Alpha_World_000@outlook.com',
#   20120721,
#   90001,
#   'CA'),
#  ('90001-054',
#   'Alpha Company 093',
#   'B',
#   203,
#   '+001 900 432-3052',
#   'Alpha_Company_093@outlook.com',
#   20060904,
#   90001,
#   'CA'),
#  ('90001-055',
#   'Beta Inc. 018',
#   'C',
#   203,
#   '+001 900 564-6105',
#   'Beta_Inc._018@outlook.com',
#   20080430,
#   90001,
#   'CA'),
#  ('90001-056',
#   'Genius Corporation 034',
#   'C',
#   203,
#   '+001 900 275-9070',
#   'Genius_Corporation_034@outlook.com',
#   20111202,
#   90001,
#   'CA'),
#  ('90001-057',
#   'Technologic Inc. 076',
#   'D',
#   203,
#   '+001 900 546-7581',
#   'Technologic_Inc._076@outlook.com',
#   20080313,
#   90001,
#   'CA'),
#  ('90001-058',
#   'Essential Store 040',
#   'D',
#   203,
#   '+001 900 423-8375',
#   'Essential_Store_040@outlook.com',
#   20091008,
#   90001,
#   'CA'),
#  ('90001-059',
#   'Alpha Company 057',
#   'B',
#   203,
#   '+001 900 607-8778',
#   'Alpha_Company_057@gmail.com.br',
#   20110104,
#   90001,
#   'CA'),
#  ('90001-060',
#   'Computer Techno 015',
#   'B',
#   203,
#   '+001 900 539-3603',
#   'Computer_Techno_015@outlook.com',
#   20091018,
#   90001,
#   'CA'),
#  ('90001-061',
#   'Computer Tech 073',
#   'B',
#   203,
#   '+001 900 232-6408',
#   'Computer_Tech_073@outlook.com',
#   20201112,
#   90001,
#   'CA'),
#  ('90001-062',
#   'High Tech Electronics 007',
#   'D',
#   203,
#   '+001 900 508-4446',
#   'High_Tech_Electronics_007@gmail.com.br',
#   20050819,
#   90001,
#   'CA'),
#  ('90001-063',
#   'Beta S.A 058',
#   'D',
#   203,
#   '+001 900 334-6674',
#   'Beta_S.A_058@outlook.com',
#   20000510,
#   90001,
#   'CA'),
#  ('90001-064',
#   'Digital Inc. 027',
#   'D',
#   203,
#   '+001 900 402-3992',
#   'Digital_Inc._027@outlook.com',
#   20200921,
#   90001,
#   'CA'),
#  ('90001-065',
#   'Genius Tech 069',
#   'B',
#   203,
#   '+001 900 981-3679',
#   'Genius_Tech_069@outlook.com',
#   20081215,
#   90001,
#   'CA'),
#  ('90001-066',
#   'Father And Sons Company 084',
#   'A',
#   203,
#   '+001 900 962-6910',
#   'Father_And_Sons_Company_084@outlook.com',
#   20120718,
#   90001,
#   'CA'),
#  ('90001-067',
#   'Computer Electronics 028',
#   'D',
#   203,
#   '+001 900 749-7199',
#   'Computer_Electronics_028@outlook.com',
#   20091006,
#   90001,
#   'CA'),
#  ('94016-001',
#   'High Tech Electronics 009',
#   'D',
#   204,
#   '+001 940 362-8034',
#   'High_Tech_Electronics_009@gmail.com.br',
#   20021128,
#   94016,
#   'CA'),
#  ('94016-002',
#   'Beta Techno 088',
#   'C',
#   204,
#   '+001 940 539-2349',
#   'Beta_Techno_088@outlook.com',
#   20000703,
#   94016,
#   'CA'),
#  ('94016-003',
#   'Genius Company 016',
#   'A',
#   204,
#   '+001 940 575-3446',
#   'Genius_Company_016@outlook.com',
#   20190510,
#   94016,
#   'CA'),
#  ('94016-004',
#   'Computer Solutions 007',
#   'D',
#   204,
#   '+001 940 935-4064',
#   'Computer_Solutions_007@outlook.com',
#   20001204,
#   94016,
#   'CA'),
#  ('94016-005',
#   'Genius Corporation 046',
#   'D',
#   204,
#   '+001 940 711-8213',
#   'Genius_Corporation_046@outlook.com',
#   20020122,
#   94016,
#   'CA'),
#  ('94016-006',
#   'Essential Electronics 006',
#   'D',
#   204,
#   '+001 940 966-5724',
#   'Essential_Electronics_006@outlook.com',
#   20110705,
#   94016,
#   'CA'),
#  ('94016-007',
#   'Essential Electronics 073',
#   'D',
#   204,
#   '+001 940 177-2821',
#   'Essential_Electronics_073@outlook.com',
#   20010927,
#   94016,
#   'CA'),
#  ('94016-008',
#   'High Tech World 081',
#   'D',
#   204,
#   '+001 940 853-8858',
#   'High_Tech_World_081@gmail.com.br',
#   20180904,
#   94016,
#   'CA'),
#  ('94016-009',
#   'Essential S.A 093',
#   'D',
#   204,
#   '+001 940 852-1977',
#   'Essential_S.A_093@gmail.com.br',
#   20020424,
#   94016,
#   'CA'),
#  ('94016-010',
#   'Father And Sons Tech 094',
#   'D',
#   204,
#   '+001 940 799-4095',
#   'Father_And_Sons_Tech_094@outlook.com',
#   20000223,
#   94016,
#   'CA'),
#  ('94016-011',
#   'Genius Electronics 001',
#   'B',
#   204,
#   '+001 940 292-5239',
#   'Genius_Electronics_001@outlook.com',
#   20190927,
#   94016,
#   'CA'),
#  ('94016-012',
#   'Beta World 049',
#   'D',
#   204,
#   '+001 940 544-5441',
#   'Beta_World_049@outlook.com',
#   20200428,
#   94016,
#   'CA'),
#  ('94016-013',
#   'Essential Corporation 037',
#   'C',
#   204,
#   '+001 940 829-5057',
#   'Essential_Corporation_037@outlook.com',
#   20151208,
#   94016,
#   'CA'),
#  ('94016-014',
#   'Computer S.A 050',
#   'C',
#   204,
#   '+001 940 221-9213',
#   'Computer_S.A_050@outlook.com',
#   20050414,
#   94016,
#   'CA'),
#  ('94016-015',
#   'Alpha Techno 075',
#   'B',
#   204,
#   '+001 940 773-8579',
#   'Alpha_Techno_075@outlook.com',
#   20071207,
#   94016,
#   'CA'),
#  ('94016-016',
#   'Father And Sons Techno 033',
#   'D',
#   204,
#   '+001 940 941-4119',
#   'Father_And_Sons_Techno_033@outlook.com',
#   20041006,
#   94016,
#   'CA'),
#  ('94016-017',
#   'Alpha Corporation 015',
#   'C',
#   204,
#   '+001 940 977-3956',
#   'Alpha_Corporation_015@outlook.com',
#   20091026,
#   94016,
#   'CA'),
#  ('94016-018',
#   'High Tech Tech 002',
#   'D',
#   204,
#   '+001 940 312-2704',
#   'High_Tech_Tech_002@outlook.com',
#   20100831,
#   94016,
#   'CA'),
#  ('94016-019',
#   'Essential Corporation 049',
#   'C',
#   204,
#   '+001 940 167-6273',
#   'Essential_Corporation_049@outlook.com',
#   20181018,
#   94016,
#   'CA'),
#  ('94016-020',
#   'Technologic Store 077',
#   'B',
#   204,
#   '+001 940 939-5129',
#   'Technologic_Store_077@outlook.com',
#   20181230,
#   94016,
#   'CA'),
#  ('94016-021',
#   'Genius Tech 063',
#   'D',
#   204,
#   '+001 940 622-2832',
#   'Genius_Tech_063@outlook.com',
#   20190222,
#   94016,
#   'CA'),
#  ('94016-022',
#   'High Tech Electronics 078',
#   'B',
#   204,
#   '+001 940 255-4544',
#   'High_Tech_Electronics_078@gmail.com.br',
#   20140126,
#   94016,
#   'CA'),
#  ('94016-023',
#   'Technologic Solutions 020',
#   'D',
#   204,
#   '+001 940 648-1923',
#   'Technologic_Solutions_020@gmail.com.br',
#   20170525,
#   94016,
#   'CA'),
#  ('94016-024',
#   'Essential Corporation 089',
#   'D',
#   204,
#   '+001 940 628-8775',
#   'Essential_Corporation_089@outlook.com',
#   20050831,
#   94016,
#   'CA'),
#  ('94016-025',
#   'Technologic Techno 031',
#   'C',
#   204,
#   '+001 940 231-3245',
#   'Technologic_Techno_031@outlook.com',
#   20100320,
#   94016,
#   'CA'),
#  ('94016-026',
#   'Alpha Store 063',
#   'C',
#   204,
#   '+001 940 289-7429',
#   'Alpha_Store_063@gmail.com.br',
#   20000615,
#   94016,
#   'CA'),
#  ('94016-027',
#   'Digital Corporation 030',
#   'C',
#   204,
#   '+001 940 607-5810',
#   'Digital_Corporation_030@outlook.com',
#   20130423,
#   94016,
#   'CA'),
#  ('94016-028',
#   'Essential Solutions 052',
#   'C',
#   204,
#   '+001 940 360-4625',
#   'Essential_Solutions_052@outlook.com',
#   20121224,
#   94016,
#   'CA'),
#  ('94016-029',
#   'Computer S.A 078',
#   'A',
#   204,
#   '+001 940 103-1335',
#   'Computer_S.A_078@outlook.com',
#   20110728,
#   94016,
#   'CA'),
#  ('94016-030',
#   'Alpha World 080',
#   'C',
#   204,
#   '+001 940 934-1247',
#   'Alpha_World_080@outlook.com',
#   20160324,
#   94016,
#   'CA'),
#  ('94016-031',
#   'Digital Store 003',
#   'D',
#   204,
#   '+001 940 667-3135',
#   'Digital_Store_003@outlook.com',
#   20170331,
#   94016,
#   'CA'),
#  ('94016-032',
#   'Technologic Tech 047',
#   'D',
#   204,
#   '+001 940 647-6301',
#   'Technologic_Tech_047@outlook.com',
#   20120313,
#   94016,
#   'CA'),
#  ('94016-033',
#   'Digital Store 046',
#   'D',
#   204,
#   '+001 940 330-6903',
#   'Digital_Store_046@outlook.com',
#   20031025,
#   94016,
#   'CA'),
#  ('94016-034',
#   'Alpha World 039',
#   'A',
#   204,
#   '+001 940 678-9155',
#   'Alpha_World_039@gmail.com.br',
#   20021012,
#   94016,
#   'CA'),
#  ('94016-035',
#   'Genius Electronics 002',
#   'C',
#   204,
#   '+001 940 212-6821',
#   'Genius_Electronics_002@gmail.com.br',
#   20150610,
#   94016,
#   'CA'),
#  ('94016-036',
#   'Digital S.A 024',
#   'C',
#   204,
#   '+001 940 408-2849',
#   'Digital_S.A_024@outlook.com',
#   20070514,
#   94016,
#   'CA'),
#  ('94016-037',
#   'Father And Sons Solutions 051',
#   'C',
#   204,
#   '+001 940 630-9442',
#   'Father_And_Sons_Solutions_051@gmail.com.br',
#   20100627,
#   94016,
#   'CA'),
#  ('94016-038',
#   'Computer Solutions 081',
#   'C',
#   204,
#   '+001 940 503-3812',
#   'Computer_Solutions_081@outlook.com',
#   20190117,
#   94016,
#   'CA'),
#  ('94016-039',
#   'Beta Electronics 046',
#   'A',
#   204,
#   '+001 940 507-5011',
#   'Beta_Electronics_046@gmail.com.br',
#   20010527,
#   94016,
#   'CA'),
#  ('94016-040',
#   'Computer Inc. 083',
#   'D',
#   204,
#   '+001 940 706-2453',
#   'Computer_Inc._083@outlook.com',
#   20160302,
#   94016,
#   'CA'),
#  ('94016-041',
#   'Digital Solutions 047',
#   'C',
#   204,
#   '+001 940 291-1773',
#   'Digital_Solutions_047@outlook.com',
#   20060613,
#   94016,
#   'CA'),
#  ('94016-042',
#   'Essential Corporation 052',
#   'D',
#   204,
#   '+001 940 886-9651',
#   'Essential_Corporation_052@gmail.com.br',
#   20120718,
#   94016,
#   'CA'),
#  ('94016-043',
#   'Genius Solutions 059',
#   'C',
#   204,
#   '+001 940 752-6917',
#   'Genius_Solutions_059@outlook.com',
#   20111206,
#   94016,
#   'CA'),
#  ('94016-044',
#   'Digital Solutions 090',
#   'D',
#   204,
#   '+001 940 546-3917',
#   'Digital_Solutions_090@outlook.com',
#   20040325,
#   94016,
#   'CA'),
#  ('94016-045',
#   'Computer Techno 061',
#   'B',
#   204,
#   '+001 940 268-5216',
#   'Computer_Techno_061@gmail.com.br',
#   20191217,
#   94016,
#   'CA'),
#  ('94016-046',
#   'High Tech Corporation 054',
#   'C',
#   204,
#   '+001 940 966-5564',
#   'High_Tech_Corporation_054@outlook.com',
#   20011231,
#   94016,
#   'CA'),
#  ('94016-047',
#   'High Tech Tech 087',
#   'B',
#   204,
#   '+001 940 501-2037',
#   'High_Tech_Tech_087@outlook.com',
#   20120525,
#   94016,
#   'CA'),
#  ('94016-048',
#   'Father And Sons S.A 043',
#   'D',
#   204,
#   '+001 940 113-5923',
#   'Father_And_Sons_S.A_043@outlook.com',
#   20000213,
#   94016,
#   'CA'),
#  ('94016-049',
#   'Computer Company 046',
#   'B',
#   204,
#   '+001 940 555-4191',
#   'Computer_Company_046@outlook.com',
#   20030812,
#   94016,
#   'CA'),
#  ('94016-050',
#   'Father And Sons Electronics 084',
#   'D',
#   204,
#   '+001 940 776-6304',
#   'Father_And_Sons_Electronics_084@outlook.com',
#   20061012,
#   94016,
#   'CA'),
#  ('94016-051',
#   'Technologic Solutions 048',
#   'A',
#   204,
#   '+001 940 602-4229',
#   'Technologic_Solutions_048@outlook.com',
#   20000217,
#   94016,
#   'CA'),
#  ('94016-052',
#   'Alpha Electronics 019',
#   'A',
#   204,
#   '+001 940 617-4589',
#   'Alpha_Electronics_019@gmail.com.br',
#   20140101,
#   94016,
#   'CA'),
#  ('94016-053',
#   'Digital Solutions 025',
#   'B',
#   204,
#   '+001 940 920-7526',
#   'Digital_Solutions_025@outlook.com',
#   20130123,
#   94016,
#   'CA'),
#  ('94016-054',
#   'Essential Tech 022',
#   'C',
#   204,
#   '+001 940 624-6700',
#   'Essential_Tech_022@outlook.com',
#   20130110,
#   94016,
#   'CA'),
#  ('94016-055',
#   'Genius Tech 023',
#   'D',
#   204,
#   '+001 940 564-4329',
#   'Genius_Tech_023@gmail.com.br',
#   20010629,
#   94016,
#   'CA'),
#  ('94016-056',
#   'Essential S.A 006',
#   'D',
#   204,
#   '+001 940 520-5706',
#   'Essential_S.A_006@gmail.com.br',
#   20170406,
#   94016,
#   'CA'),
#  ('94016-057',
#   'Alpha Store 028',
#   'D',
#   204,
#   '+001 940 605-6363',
#   'Alpha_Store_028@gmail.com.br',
#   20181003,
#   94016,
#   'CA'),
#  ('94016-058',
#   'Technologic S.A 085',
#   'C',
#   204,
#   '+001 940 257-8079',
#   'Technologic_S.A_085@outlook.com',
#   20200514,
#   94016,
#   'CA'),
#  ('94016-059',
#   'Beta Tech 069',
#   'C',
#   204,
#   '+001 940 337-7864',
#   'Beta_Tech_069@gmail.com.br',
#   20000525,
#   94016,
#   'CA'),
#  ('94016-060',
#   'Computer Solutions 027',
#   'D',
#   204,
#   '+001 940 389-1447',
#   'Computer_Solutions_027@outlook.com',
#   20000628,
#   94016,
#   'CA'),
#  ('94016-061',
#   'Beta Tech 047',
#   'B',
#   204,
#   '+001 940 910-8099',
#   'Beta_Tech_047@gmail.com.br',
#   20090222,
#   94016,
#   'CA'),
#  ('94016-062',
#   'Essential Corporation 038',
#   'D',
#   204,
#   '+001 940 620-8375',
#   'Essential_Corporation_038@gmail.com.br',
#   20011025,
#   94016,
#   'CA'),
#  ('94016-063',
#   'Father And Sons World 051',
#   'D',
#   204,
#   '+001 940 830-6164',
#   'Father_And_Sons_World_051@outlook.com',
#   20020408,
#   94016,
#   'CA'),
#  ('94016-064',
#   'Technologic World 023',
#   'C',
#   204,
#   '+001 940 791-4590',
#   'Technologic_World_023@outlook.com',
#   20061116,
#   94016,
#   'CA'),
#  ('94016-065',
#   'Genius Company 031',
#   'D',
#   204,
#   '+001 940 522-5938',
#   'Genius_Company_031@outlook.com',
#   20060125,
#   94016,
#   'CA'),
#  ('94016-066',
#   'Father And Sons S.A 006',
#   'B',
#   204,
#   '+001 940 811-3528',
#   'Father_And_Sons_S.A_006@outlook.com',
#   20040927,
#   94016,
#   'CA'),
#  ('94016-067',
#   'Digital Store 093',
#   'D',
#   204,
#   '+001 940 389-2026',
#   'Digital_Store_093@gmail.com.br',
#   20061016,
#   94016,
#   'CA'),
#  ('94016-068',
#   'High Tech Techno 049',
#   'C',
#   204,
#   '+001 940 817-7096',
#   'High_Tech_Techno_049@gmail.com.br',
#   20000804,
#   94016,
#   'CA'),
#  ('94016-069',
#   'Beta Store 072',
#   'D',
#   204,
#   '+001 940 112-3307',
#   'Beta_Store_072@gmail.com.br',
#   20020511,
#   94016,
#   'CA'),
#  ('94016-070',
#   'Essential World 057',
#   'D',
#   204,
#   '+001 940 195-1162',
#   'Essential_World_057@outlook.com',
#   20140329,
#   94016,
#   'CA'),
#  ('94016-071',
#   'Essential Store 077',
#   'D',
#   204,
#   '+001 940 650-8412',
#   'Essential_Store_077@gmail.com.br',
#   20100223,
#   94016,
#   'CA'),
#  ('30301-001',
#   'Technologic Inc. 023',
#   'B',
#   205,
#   '+001 303 155-1704',
#   'Technologic_Inc._023@outlook.com',
#   20000918,
#   30301,
#   'GA'),
#  ('30301-002',
#   'Technologic Electronics 083',
#   'D',
#   205,
#   '+001 303 561-3839',
#   'Technologic_Electronics_083@outlook.com',
#   20050720,
#   30301,
#   'GA'),
#  ('30301-003',
#   'High Tech Techno 067',
#   'B',
#   205,
#   '+001 303 193-7129',
#   'High_Tech_Techno_067@outlook.com',
#   20031127,
#   30301,
#   'GA'),
#  ('30301-004',
#   'Beta Inc. 063',
#   'D',
#   205,
#   '+001 303 747-3526',
#   'Beta_Inc._063@outlook.com',
#   20140402,
#   30301,
#   'GA'),
#  ('30301-005',
#   'Alpha Company 056',
#   'D',
#   205,
#   '+001 303 439-8835',
#   'Alpha_Company_056@outlook.com',
#   20150307,
#   30301,
#   'GA'),
#  ('30301-006',
#   'Computer Inc. 046',
#   'D',
#   205,
#   '+001 303 328-6820',
#   'Computer_Inc._046@outlook.com',
#   20170427,
#   30301,
#   'GA'),
#  ('30301-007',
#   'Beta Store 037',
#   'B',
#   205,
#   '+001 303 434-1925',
#   'Beta_Store_037@gmail.com.br',
#   20080901,
#   30301,
#   'GA'),
#  ('30301-008',
#   'High Tech Electronics 039',
#   'D',
#   205,
#   '+001 303 688-6673',
#   'High_Tech_Electronics_039@outlook.com',
#   20150425,
#   30301,
#   'GA'),
#  ('30301-009',
#   'High Tech Techno 037',
#   'D',
#   205,
#   '+001 303 939-5071',
#   'High_Tech_Techno_037@gmail.com.br',
#   20170224,
#   30301,
#   'GA'),
#  ('30301-010',
#   'Technologic World 094',
#   'D',
#   205,
#   '+001 303 731-6303',
#   'Technologic_World_094@outlook.com',
#   20060729,
#   30301,
#   'GA'),
#  ('30301-011',
#   'Alpha Inc. 000',
#   'C',
#   205,
#   '+001 303 567-1002',
#   'Alpha_Inc._000@outlook.com',
#   20010106,
#   30301,
#   'GA'),
#  ('30301-012',
#   'Genius Techno 013',
#   'D',
#   205,
#   '+001 303 486-7984',
#   'Genius_Techno_013@gmail.com.br',
#   20100228,
#   30301,
#   'GA'),
#  ('30301-013',
#   'High Tech Techno 008',
#   'D',
#   205,
#   '+001 303 363-1549',
#   'High_Tech_Techno_008@outlook.com',
#   20070522,
#   30301,
#   'GA'),
#  ('30301-014',
#   'Digital Company 077',
#   'D',
#   205,
#   '+001 303 115-1361',
#   'Digital_Company_077@outlook.com',
#   20190914,
#   30301,
#   'GA'),
#  ('30301-015',
#   'High Tech Corporation 043',
#   'D',
#   205,
#   '+001 303 867-7620',
#   'High_Tech_Corporation_043@outlook.com',
#   20170920,
#   30301,
#   'GA'),
#  ('30301-016',
#   'High Tech Inc. 022',
#   'B',
#   205,
#   '+001 303 866-3583',
#   'High_Tech_Inc._022@gmail.com.br',
#   20020928,
#   30301,
#   'GA'),
#  ('30301-017',
#   'Alpha Tech 001',
#   'D',
#   205,
#   '+001 303 608-4589',
#   'Alpha_Tech_001@outlook.com',
#   20120507,
#   30301,
#   'GA'),
#  ('30301-018',
#   'High Tech S.A 075',
#   'D',
#   205,
#   '+001 303 546-1780',
#   'High_Tech_S.A_075@gmail.com.br',
#   20070925,
#   30301,
#   'GA'),
#  ('30301-019',
#   'High Tech World 066',
#   'D',
#   205,
#   '+001 303 129-4217',
#   'High_Tech_World_066@outlook.com',
#   20090407,
#   30301,
#   'GA'),
#  ('30301-020',
#   'Genius Tech 092',
#   'A',
#   205,
#   '+001 303 456-1819',
#   'Genius_Tech_092@outlook.com',
#   20131227,
#   30301,
#   'GA'),
#  ('30301-021',
#   'Essential Solutions 089',
#   'C',
#   205,
#   '+001 303 124-9574',
#   'Essential_Solutions_089@outlook.com',
#   20160530,
#   30301,
#   'GA'),
#  ('30301-022',
#   'Alpha Electronics 066',
#   'D',
#   205,
#   '+001 303 788-1203',
#   'Alpha_Electronics_066@outlook.com',
#   20170204,
#   30301,
#   'GA'),
#  ('30301-023',
#   'Genius Store 071',
#   'D',
#   205,
#   '+001 303 167-9270',
#   'Genius_Store_071@outlook.com',
#   20130215,
#   30301,
#   'GA'),
#  ('30301-024',
#   'Computer Corporation 051',
#   'B',
#   205,
#   '+001 303 674-5347',
#   'Computer_Corporation_051@outlook.com',
#   20040923,
#   30301,
#   'GA'),
#  ('30301-025',
#   'Technologic Corporation 023',
#   'D',
#   205,
#   '+001 303 923-4155',
#   'Technologic_Corporation_023@outlook.com',
#   20121209,
#   30301,
#   'GA'),
#  ('30301-026',
#   'Genius Techno 047',
#   'C',
#   205,
#   '+001 303 691-4334',
#   'Genius_Techno_047@outlook.com',
#   20070622,
#   30301,
#   'GA'),
#  ('30301-027',
#   'High Tech Techno 017',
#   'D',
#   205,
#   '+001 303 493-5846',
#   'High_Tech_Techno_017@outlook.com',
#   20050821,
#   30301,
#   'GA'),
#  ('30301-028',
#   'Essential Corporation 055',
#   'D',
#   205,
#   '+001 303 751-4854',
#   'Essential_Corporation_055@gmail.com.br',
#   20020509,
#   30301,
#   'GA'),
#  ('30301-029',
#   'Essential Electronics 019',
#   'D',
#   205,
#   '+001 303 992-3346',
#   'Essential_Electronics_019@outlook.com',
#   20120907,
#   30301,
#   'GA'),
#  ('30301-030',
#   'Beta Corporation 013',
#   'C',
#   205,
#   '+001 303 314-5515',
#   'Beta_Corporation_013@outlook.com',
#   20010429,
#   30301,
#   'GA'),
#  ('30301-031',
#   'Alpha Corporation 072',
#   'D',
#   205,
#   '+001 303 912-5669',
#   'Alpha_Corporation_072@outlook.com',
#   20171202,
#   30301,
#   'GA'),
#  ('30301-032',
#   'Alpha Company 080',
#   'A',
#   205,
#   '+001 303 292-1497',
#   'Alpha_Company_080@outlook.com',
#   20011207,
#   30301,
#   'GA'),
#  ('30301-033',
#   'Computer World 025',
#   'D',
#   205,
#   '+001 303 575-3160',
#   'Computer_World_025@outlook.com',
#   20151021,
#   30301,
#   'GA'),
#  ('30301-034',
#   'Digital Corporation 002',
#   'B',
#   205,
#   '+001 303 173-2683',
#   'Digital_Corporation_002@outlook.com',
#   20200820,
#   30301,
#   'GA'),
#  ('30301-035',
#   'Technologic Inc. 084',
#   'C',
#   205,
#   '+001 303 418-9434',
#   'Technologic_Inc._084@gmail.com.br',
#   20020417,
#   30301,
#   'GA'),
#  ('30301-036',
#   'Computer Company 041',
#   'D',
#   205,
#   '+001 303 581-4436',
#   'Computer_Company_041@gmail.com.br',
#   20041001,
#   30301,
#   'GA'),
#  ('30301-037',
#   'Technologic Company 034',
#   'C',
#   205,
#   '+001 303 870-7710',
#   'Technologic_Company_034@outlook.com',
#   20171226,
#   30301,
#   'GA'),
#  ('30301-038',
#   'Beta Solutions 006',
#   'D',
#   205,
#   '+001 303 535-8512',
#   'Beta_Solutions_006@gmail.com.br',
#   20011015,
#   30301,
#   'GA'),
#  ('30301-039',
#   'Digital Inc. 036',
#   'D',
#   205,
#   '+001 303 874-3568',
#   'Digital_Inc._036@gmail.com.br',
#   20051004,
#   30301,
#   'GA'),
#  ('30301-040',
#   'High Tech Solutions 017',
#   'D',
#   205,
#   '+001 303 464-6913',
#   'High_Tech_Solutions_017@outlook.com',
#   20001206,
#   30301,
#   'GA'),
#  ('30301-041',
#   'Computer Store 046',
#   'D',
#   205,
#   '+001 303 195-1404',
#   'Computer_Store_046@gmail.com.br',
#   20140730,
#   30301,
#   'GA'),
#  ('30301-042',
#   'Computer Inc. 024',
#   'D',
#   205,
#   '+001 303 940-2050',
#   'Computer_Inc._024@outlook.com',
#   20070424,
#   30301,
#   'GA'),
#  ('30301-043',
#   'Technologic Corporation 079',
#   'D',
#   205,
#   '+001 303 370-7709',
#   'Technologic_Corporation_079@outlook.com',
#   20090710,
#   30301,
#   'GA'),
#  ('30301-044',
#   'Father And Sons Techno 054',
#   'D',
#   205,
#   '+001 303 149-2883',
#   'Father_And_Sons_Techno_054@gmail.com.br',
#   20191019,
#   30301,
#   'GA'),
#  ('30301-045',
#   'Genius Electronics 097',
#   'D',
#   205,
#   '+001 303 626-2646',
#   'Genius_Electronics_097@outlook.com',
#   20160409,
#   30301,
#   'GA'),
#  ('30301-046',
#   'Computer Solutions 009',
#   'D',
#   205,
#   '+001 303 551-5653',
#   'Computer_Solutions_009@outlook.com',
#   20181001,
#   30301,
#   'GA'),
#  ('30301-047',
#   'Technologic Solutions 099',
#   'D',
#   205,
#   '+001 303 715-8959',
#   'Technologic_Solutions_099@outlook.com',
#   20001203,
#   30301,
#   'GA'),
#  ('30301-048',
#   'Father And Sons Electronics 021',
#   'B',
#   205,
#   '+001 303 422-5992',
#   'Father_And_Sons_Electronics_021@gmail.com.br',
#   20020507,
#   30301,
#   'GA'),
#  ('30301-049',
#   'Technologic Solutions 003',
#   'C',
#   205,
#   '+001 303 537-3393',
#   'Technologic_Solutions_003@outlook.com',
#   20140413,
#   30301,
#   'GA'),
#  ('30301-050',
#   'Father And Sons Solutions 089',
#   'B',
#   205,
#   '+001 303 630-9372',
#   'Father_And_Sons_Solutions_089@outlook.com',
#   20050627,
#   30301,
#   'GA'),
#  ('30301-051',
#   'Computer Company 043',
#   'D',
#   205,
#   '+001 303 385-5613',
#   'Computer_Company_043@outlook.com',
#   20061111,
#   30301,
#   'GA'),
#  ('30301-052',
#   'Digital Company 004',
#   'D',
#   205,
#   '+001 303 157-1557',
#   'Digital_Company_004@outlook.com',
#   20170113,
#   30301,
#   'GA'),
#  ('30301-053',
#   'Technologic Solutions 018',
#   'C',
#   205,
#   '+001 303 163-2360',
#   'Technologic_Solutions_018@outlook.com',
#   20040911,
#   30301,
#   'GA'),
#  ('30301-054',
#   'Alpha Solutions 076',
#   'D',
#   205,
#   '+001 303 203-4501',
#   'Alpha_Solutions_076@outlook.com',
#   20020414,
#   30301,
#   'GA'),
#  ('30301-055',
#   'High Tech Inc. 068',
#   'D',
#   205,
#   '+001 303 550-1086',
#   'High_Tech_Inc._068@outlook.com',
#   20010702,
#   30301,
#   'GA'),
#  ('30301-056',
#   'Technologic World 092',
#   'C',
#   205,
#   '+001 303 673-9850',
#   'Technologic_World_092@outlook.com',
#   20111201,
#   30301,
#   'GA'),
#  ('30301-057',
#   'Computer Company 058',
#   'C',
# ...
#  ('02215-029',
#   'Technologic Store 071',
#   'D',
#   109,
#   '+001 022 140-1589',
#   'Technologic_Store_071@outlook.com',
#   20200109,
#   2215,
#   'MA'),
#  ('02215-030',
#   'Essential Solutions 007',
#   'D',
#   109,
#   '+001 022 611-8787',
#   'Essential_Solutions_007@outlook.com',
#   20101115,
#   2215,
#   'MA'),
#  ('02215-031',
#   'Essential Electronics 038',
#   'D',
#   109,
#   '+001 022 772-5296',
#   'Essential_Electronics_038@outlook.com',
#   20120113,
#   2215,
#   'MA'),
#  ('02215-032',
#   'Essential Corporation 004',
#   'D',
#   109,
#   '+001 022 419-4525',
#   'Essential_Corporation_004@gmail.com.br',
#   20100905,
#   2215,
#   'MA'),
#  ('02215-033',
#   'Alpha S.A 017',
#   'C',
#   109,
#   '+001 022 526-9861',
#   'Alpha_S.A_017@gmail.com.br',
#   20070621,
#   2215,
#   'MA'),
#  ('02215-034',
#   'High Tech S.A 093',
#   'D',
#   109,
#   '+001 022 384-3296',
#   'High_Tech_S.A_093@gmail.com.br',
#   20180827,
#   2215,
#   'MA'),
#  ('02215-035',
#   'Essential World 088',
#   'C',
#   109,
#   '+001 022 138-8561',
#   'Essential_World_088@outlook.com',
#   20200729,
#   2215,
#   'MA'),
#  ('02215-036',
#   'Technologic Store 051',
#   'D',
#   109,
#   '+001 022 351-7110',
#   'Technologic_Store_051@outlook.com',
#   20050121,
#   2215,
#   'MA'),
#  ('02215-037',
#   'Alpha Electronics 029',
#   'C',
#   109,
#   '+001 022 127-6467',
#   'Alpha_Electronics_029@outlook.com',
#   20000309,
#   2215,
#   'MA'),
#  ('98101-001',
#   'Father And Sons S.A 081',
#   'B',
#   110,
#   '+001 981 690-1864',
#   'Father_And_Sons_S.A_081@outlook.com',
#   20131215,
#   98101,
#   'WA'),
#  ('98101-002',
#   'Father And Sons Corporation 008',
#   'D',
#   110,
#   '+001 981 585-4188',
#   'Father_And_Sons_Corporation_008@gmail.com.br',
#   20200801,
#   98101,
#   'WA'),
#  ('98101-003',
#   'Beta Inc. 040',
#   'C',
#   110,
#   '+001 981 827-9109',
#   'Beta_Inc._040@outlook.com',
#   20130725,
#   98101,
#   'WA'),
#  ('98101-004',
#   'Father And Sons Techno 022',
#   'D',
#   110,
#   '+001 981 361-8850',
#   'Father_And_Sons_Techno_022@outlook.com',
#   20030528,
#   98101,
#   'WA'),
#  ('98101-005',
#   'Essential Electronics 100',
#   'D',
#   110,
#   '+001 981 979-9086',
#   'Essential_Electronics_100@gmail.com.br',
#   20200403,
#   98101,
#   'WA'),
#  ('98101-006',
#   'Technologic Solutions 022',
#   'D',
#   110,
#   '+001 981 270-7219',
#   'Technologic_Solutions_022@outlook.com',
#   20130701,
#   98101,
#   'WA'),
#  ('98101-007',
#   'Digital Store 032',
#   'D',
#   110,
#   '+001 981 544-8942',
#   'Digital_Store_032@gmail.com.br',
#   20000326,
#   98101,
#   'WA'),
#  ('98101-008',
#   'Father And Sons S.A 076',
#   'C',
#   110,
#   '+001 981 802-5443',
#   'Father_And_Sons_S.A_076@outlook.com',
#   20110403,
#   98101,
#   'WA'),
#  ('98101-009',
#   'Beta World 010',
#   'D',
#   110,
#   '+001 981 109-9843',
#   'Beta_World_010@outlook.com',
#   20101109,
#   98101,
#   'WA'),
#  ('98101-010',
#   'Father And Sons Tech 058',
#   'D',
#   110,
#   '+001 981 967-2230',
#   'Father_And_Sons_Tech_058@outlook.com',
#   20131201,
#   98101,
#   'WA'),
#  ('98101-011',
#   'Technologic World 081',
#   'D',
#   110,
#   '+001 981 448-1363',
#   'Technologic_World_081@outlook.com',
#   20060520,
#   98101,
#   'WA'),
#  ('98101-012',
#   'Essential Corporation 096',
#   'D',
#   110,
#   '+001 981 183-4781',
#   'Essential_Corporation_096@gmail.com.br',
#   20100918,
#   98101,
#   'WA'),
#  ('98101-013',
#   'Father And Sons S.A 049',
#   'D',
#   110,
#   '+001 981 393-5453',
#   'Father_And_Sons_S.A_049@outlook.com',
#   20081101,
#   98101,
#   'WA'),
#  ('98101-014',
#   'Computer Electronics 097',
#   'C',
#   110,
#   '+001 981 478-4635',
#   'Computer_Electronics_097@outlook.com',
#   20190101,
#   98101,
#   'WA'),
#  ('98101-015',
#   'Digital Company 023',
#   'D',
#   110,
#   '+001 981 841-9950',
#   'Digital_Company_023@outlook.com',
#   20020506,
#   98101,
#   'WA'),
#  ('98101-016',
#   'Alpha Store 071',
#   'D',
#   110,
#   '+001 981 718-9058',
#   'Alpha_Store_071@outlook.com',
#   20190406,
#   98101,
#   'WA'),
#  ('98101-017',
#   'High Tech Electronics 038',
#   'C',
#   110,
#   '+001 981 939-3274',
#   'High_Tech_Electronics_038@gmail.com.br',
#   20180417,
#   98101,
#   'WA'),
#  ('98101-018',
#   'Computer Solutions 088',
#   'D',
#   110,
#   '+001 981 455-3737',
#   'Computer_Solutions_088@outlook.com',
#   20200107,
#   98101,
#   'WA'),
#  ('98101-019',
#   'Digital S.A 018',
#   'C',
#   110,
#   '+001 981 438-7095',
#   'Digital_S.A_018@outlook.com',
#   20100317,
#   98101,
#   'WA'),
#  ('98101-020',
#   'Father And Sons Store 064',
#   'B',
#   110,
#   '+001 981 505-5864',
#   'Father_And_Sons_Store_064@outlook.com',
#   20161127,
#   98101,
#   'WA'),
#  ('98101-021',
#   'Computer Techno 050',
#   'D',
#   110,
#   '+001 981 388-9747',
#   'Computer_Techno_050@outlook.com',
#   20080109,
#   98101,
#   'WA'),
#  ('98101-022',
#   'Computer Inc. 021',
#   'D',
#   110,
#   '+001 981 486-1754',
#   'Computer_Inc._021@gmail.com.br',
#   20121010,
#   98101,
#   'WA'),
#  ('98101-023',
#   'Alpha Solutions 082',
#   'D',
#   110,
#   '+001 981 282-8510',
#   'Alpha_Solutions_082@outlook.com',
#   20200223,
#   98101,
#   'WA'),
#  ('98101-024',
#   'Alpha Inc. 047',
#   'C',
#   110,
#   '+001 981 988-1740',
#   'Alpha_Inc._047@gmail.com.br',
#   20040723,
#   98101,
#   'WA'),
#  ('98101-025',
#   'Computer Tech 017',
#   'A',
#   110,
#   '+001 981 780-5753',
#   'Computer_Tech_017@outlook.com',
#   20110112,
#   98101,
#   'WA'),
#  ('98101-026',
#   'Beta Corporation 014',
#   'B',
#   110,
#   '+001 981 373-5592',
#   'Beta_Corporation_014@outlook.com',
#   20050808,
#   98101,
#   'WA'),
#  ('98101-027',
#   'Alpha S.A 014',
#   'D',
#   110,
#   '+001 981 580-1503',
#   'Alpha_S.A_014@gmail.com.br',
#   20060102,
#   98101,
#   'WA'),
#  ('98101-028',
#   'Genius S.A 032',
#   'D',
#   110,
#   '+001 981 118-7347',
#   'Genius_S.A_032@outlook.com',
#   20011122,
#   98101,
#   'WA'),
#  ('98101-029',
#   'Beta Electronics 092',
#   'D',
#   110,
#   '+001 981 802-6355',
#   'Beta_Electronics_092@outlook.com',
#   20011030,
#   98101,
#   'WA'),
#  ('98101-030',
#   'Technologic S.A 026',
#   'C',
#   110,
#   '+001 981 978-4823',
#   'Technologic_S.A_026@outlook.com',
#   20011103,
#   98101,
#   'WA'),
#  ('98101-031',
#   'Father And Sons Store 038',
#   'C',
#   110,
#   '+001 981 336-5944',
#   'Father_And_Sons_Store_038@gmail.com.br',
#   20171006,
#   98101,
#   'WA'),
#  ('98101-032',
#   'High Tech Electronics 053',
#   'D',
#   110,
#   '+001 981 357-8605',
#   'High_Tech_Electronics_053@outlook.com',
#   20180218,
#   98101,
#   'WA'),
#  ('98101-033',
#   'Alpha Electronics 074',
#   'C',
#   110,
#   '+001 981 760-9876',
#   'Alpha_Electronics_074@outlook.com',
#   20060619,
#   98101,
#   'WA'),
#  ('98101-034',
#   'Computer Company 026',
#   'D',
#   110,
#   '+001 981 754-1687',
#   'Computer_Company_026@outlook.com',
#   20200102,
#   98101,
#   'WA'),
#  ('98101-035',
#   'Genius World 018',
#   'D',
#   110,
#   '+001 981 100-2420',
#   'Genius_World_018@outlook.com',
#   20111203,
#   98101,
#   'WA'),
#  ('98101-036',
#   'Father And Sons Electronics 086',
#   'B',
#   110,
#   '+001 981 368-3922',
#   'Father_And_Sons_Electronics_086@outlook.com',
#   20150707,
#   98101,
#   'WA'),
#  ('98101-037',
#   'Essential Solutions 010',
#   'D',
#   110,
#   '+001 981 947-8843',
#   'Essential_Solutions_010@gmail.com.br',
#   20191212,
#   98101,
#   'WA'),
#  ('98101-038',
#   'High Tech Solutions 047',
#   'C',
#   110,
#   '+001 981 895-9534',
#   'High_Tech_Solutions_047@outlook.com',
#   20001212,
#   98101,
#   'WA'),
#  ('98101-039',
#   'Computer Store 077',
#   'C',
#   110,
#   '+001 981 337-5824',
#   'Computer_Store_077@outlook.com',
#   20080816,
#   98101,
#   'WA'),
#  ('98101-040',
#   'Alpha Corporation 064',
#   'C',
#   110,
#   '+001 981 175-3235',
#   'Alpha_Corporation_064@outlook.com',
#   20021119,
#   98101,
#   'WA'),
#  ('98101-041',
#   'Digital S.A 033',
#   'D',
#   110,
#   '+001 981 785-2402',
#   'Digital_S.A_033@outlook.com',
#   20150130,
#   98101,
#   'WA'),
#  ('98101-042',
#   'Genius World 004',
#   'B',
#   110,
#   '+001 981 350-6490',
#   'Genius_World_004@outlook.com',
#   20011203,
#   98101,
#   'WA'),
#  ('98101-043',
#   'Alpha World 022',
#   'C',
#   110,
#   '+001 981 952-4794',
#   'Alpha_World_022@outlook.com',
#   20170310,
#   98101,
#   'WA'),
#  ('98101-044',
#   'Digital Company 097',
#   'D',
#   110,
#   '+001 981 805-3240',
#   'Digital_Company_097@outlook.com',
#   20120414,
#   98101,
#   'WA'),
#  ('98101-045',
#   'Genius Inc. 049',
#   'D',
#   110,
#   '+001 981 419-1293',
#   'Genius_Inc._049@gmail.com.br',
#   20081007,
#   98101,
#   'WA'),
#  ('98101-046',
#   'Genius World 084',
#   'D',
#   110,
#   '+001 981 365-1422',
#   'Genius_World_084@outlook.com',
#   20170905,
#   98101,
#   'WA'),
#  ('98101-047',
#   'Technologic Inc. 037',
#   'C',
#   110,
#   '+001 981 354-2500',
#   'Technologic_Inc._037@outlook.com',
#   20100424,
#   98101,
#   'WA'),
#  ('98101-048',
#   'Beta Company 033',
#   'D',
#   110,
#   '+001 981 789-3433',
#   'Beta_Company_033@gmail.com.br',
#   20071202,
#   98101,
#   'WA'),
#  ('98101-049',
#   'Genius Solutions 051',
#   'D',
#   110,
#   '+001 981 934-8468',
#   'Genius_Solutions_051@gmail.com.br',
#   20140719,
#   98101,
#   'WA'),
#  ('98101-050',
#   'Essential Tech 099',
#   'A',
#   110,
#   '+001 981 726-7927',
#   'Essential_Tech_099@outlook.com',
#   20160126,
#   98101,
#   'WA'),
#  ('98101-051',
#   'Essential Store 098',
#   'C',
#   110,
#   '+001 981 344-5598',
#   'Essential_Store_098@outlook.com',
#   20020609,
#   98101,
#   'WA'),
#  ('98101-052',
#   'Computer Electronics 046',
#   'C',
#   110,
#   '+001 981 930-7148',
#   'Computer_Electronics_046@gmail.com.br',
#   20030401,
#   98101,
#   'WA'),
#  ('98101-053',
#   'Computer Company 079',
#   'D',
#   110,
#   '+001 981 910-6937',
#   'Computer_Company_079@gmail.com.br',
#   20080524,
#   98101,
#   'WA'),
#  ('98101-054',
#   'High Tech Corporation 081',
#   'D',
#   110,
#   '+001 981 148-6055',
#   'High_Tech_Corporation_081@outlook.com',
#   20011111,
#   98101,
#   'WA'),
#  ('98101-055',
#   'Essential Tech 073',
#   'D',
#   110,
#   '+001 981 570-8461',
#   'Essential_Tech_073@outlook.com',
#   20031224,
#   98101,
#   'WA'),
#  ('98101-056',
#   'Computer Solutions 004',
#   'D',
#   110,
#   '+001 981 267-4847',
#   'Computer_Solutions_004@outlook.com',
#   20190312,
#   98101,
#   'WA'),
#  ('98101-057',
#   'Technologic Store 001',
#   'D',
#   110,
#   '+001 981 322-8660',
#   'Technologic_Store_001@gmail.com.br',
#   20010125,
#   98101,
#   'WA'),
#  ('98101-058',
#   'Alpha S.A 039',
#   'D',
#   110,
#   '+001 981 128-2862',
#   'Alpha_S.A_039@gmail.com.br',
#   20170309,
#   98101,
#   'WA'),
#  ('98101-059',
#   'Essential Corporation 054',
#   'D',
#   110,
#   '+001 981 974-8558',
#   'Essential_Corporation_054@gmail.com.br',
#   20201216,
#   98101,
#   'WA'),
#  ('98101-060',
#   'Genius Store 030',
#   'C',
#   110,
#   '+001 981 210-9099',
#   'Genius_Store_030@outlook.com',
#   20090316,
#   98101,
#   'WA'),
#  ('98101-061',
#   'Father And Sons Tech 072',
#   'A',
#   110,
#   '+001 981 582-1713',
#   'Father_And_Sons_Tech_072@outlook.com',
#   20080711,
#   98101,
#   'WA'),
#  ('98101-062',
#   'Father And Sons Electronics 052',
#   'C',
#   110,
#   '+001 981 699-2491',
#   'Father_And_Sons_Electronics_052@outlook.com',
#   20100718,
#   98101,
#   'WA'),
#  ('98101-063',
#   'Father And Sons Corporation 068',
#   'D',
#   110,
#   '+001 981 145-6065',
#   'Father_And_Sons_Corporation_068@gmail.com.br',
#   20130904,
#   98101,
#   'WA'),
#  ('98101-064',
#   'Father And Sons S.A 098',
#   'D',
#   110,
#   '+001 981 291-9872',
#   'Father_And_Sons_S.A_098@outlook.com',
#   20140517,
#   98101,
#   'WA'),
#  ('98101-065',
#   'Technologic Inc. 052',
#   'C',
#   110,
#   '+001 981 329-2514',
#   'Technologic_Inc._052@outlook.com',
#   20190703,
#   98101,
#   'WA'),
#  ('98101-066',
#   'Father And Sons World 056',
#   'D',
#   110,
#   '+001 981 870-9816',
#   'Father_And_Sons_World_056@outlook.com',
#   20000913,
#   98101,
#   'WA'),
#  ('98101-067',
#   'Genius Techno 060',
#   'B',
#   110,
#   '+001 981 297-4441',
#   'Genius_Techno_060@outlook.com',
#   20120929,
#   98101,
#   'WA'),
#  ('98101-068',
#   'Genius World 037',
#   'C',
#   110,
#   '+001 981 140-1787',
#   'Genius_World_037@outlook.com',
#   20190325,
#   98101,
#   'WA'),
#  ('98101-069',
#   'Digital Company 008',
#   'C',
#   110,
#   '+001 981 541-2535',
#   'Digital_Company_008@outlook.com',
#   20201215,
#   98101,
#   'WA'),
#  ('98101-070',
#   'High Tech Electronics 004',
#   'D',
#   110,
#   '+001 981 763-2301',
#   'High_Tech_Electronics_004@gmail.com.br',
#   20170325,
#   98101,
#   'WA'),
#  ('98101-071',
#   'Digital Electronics 036',
#   'C',
#   110,
#   '+001 981 856-5398',
#   'Digital_Electronics_036@outlook.com',
#   20180317,
#   98101,
#   'WA'),
#  ('98101-072',
#   'Computer Electronics 084',
#   'D',
#   110,
#   '+001 981 925-6371',
#   'Computer_Electronics_084@gmail.com.br',
#   20171224,
#   98101,
#   'WA'),
#  ('98101-073',
#   'Digital Corporation 025',
#   'D',
#   110,
#   '+001 981 814-7468',
#   'Digital_Corporation_025@gmail.com.br',
#   20000728,
#   98101,
#   'WA'),
#  ('98101-074',
#   'Beta S.A 086',
#   'D',
#   110,
#   '+001 981 457-2885',
#   'Beta_S.A_086@gmail.com.br',
#   20040429,
#   98101,
#   'WA'),
#  ('98101-075',
#   'Computer Electronics 051',
#   'D',
#   110,
#   '+001 981 650-9881',
#   'Computer_Electronics_051@outlook.com',
#   20030906,
#   98101,
#   'WA'),
#  ('98101-076',
#   'Digital Tech 028',
#   'A',
#   110,
#   '+001 981 856-3766',
#   'Digital_Tech_028@outlook.com',
#   20091217,
#   98101,
#   'WA'),
#  ('98101-077',
#   'Computer Company 030',
#   'D',
#   110,
#   '+001 981 689-1204',
#   'Computer_Company_030@outlook.com',
#   20100118,
#   98101,
#   'WA'),
#  ('98101-078',
#   'Alpha Electronics 073',
#   'D',
#   110,
#   '+001 981 802-5798',
#   'Alpha_Electronics_073@outlook.com',
#   20200229,
#   98101,
#   'WA'),
#  ('98101-079',
#   'Computer S.A 026',
#   'B',
#   110,
#   '+001 981 806-6488',
#   'Computer_S.A_026@outlook.com',
#   20070512,
#   98101,
#   'WA'),
#  ('98101-080',
#   'Father And Sons S.A 009',
#   'D',
#   110,
#   '+001 981 539-9644',
#   'Father_And_Sons_S.A_009@outlook.com',
#   20170611,
#   98101,
#   'WA'),
#  ('98101-081',
#   'Computer Company 099',
#   'D',
#   110,
#   '+001 981 669-7675',
#   'Computer_Company_099@outlook.com',
#   20020221,
#   98101,
#   'WA'),
#  ('98101-082',
#   'Father And Sons Tech 080',
#   'B',
#   110,
#   '+001 981 284-7197',
#   'Father_And_Sons_Tech_080@outlook.com',
#   20121101,
#   98101,
#   'WA'),
#  ('98101-083',
#   'Alpha Corporation 039',
#   'D',
#   110,
#   '+001 981 718-3660',
#   'Alpha_Corporation_039@outlook.com',
#   20170604,
#   98101,
#   'WA'),
#  ('98101-084',
#   'High Tech World 047',
#   'B',
#   110,
#   '+001 981 241-2220',
#   'High_Tech_World_047@outlook.com',
#   20100720,
#   98101,
#   'WA'),
#  ('98101-085',
#   'Digital Inc. 054',
#   'C',
#   110,
#   '+001 981 330-9379',
#   'Digital_Inc._054@outlook.com',
#   20150202,
#   98101,
#   'WA'),
#  ('98101-086',
#   'Genius Inc. 075',
#   'C',
#   110,
#   '+001 981 957-8503',
#   'Genius_Inc._075@gmail.com.br',
#   20000604,
#   98101,
#   'WA'),
#  ('98101-087',
#   'Essential Techno 040',
#   'D',
#   110,
#   '+001 981 269-5333',
#   'Essential_Techno_040@outlook.com',
#   20031223,
#   98101,
#   'WA'),
#  ('98101-088',
#   'Essential Store 006',
#   'D',
#   110,
#   '+001 981 475-1072',
#   'Essential_Store_006@outlook.com',
#   20100127,
#   98101,
#   'WA'),
#  ('98101-089',
#   'Beta Techno 089',
#   'D',
#   110,
#   '+001 981 748-8710',
#   'Beta_Techno_089@outlook.com',
#   20140906,
#   98101,
#   'WA'),
#  ('98101-090',
#   'Computer Corporation 005',
#   'D',
#   110,
#   '+001 981 631-9789',
#   'Computer_Corporation_005@outlook.com',
#   20171024,
#   98101,
#   'WA'),
#  ('98101-091',
#   'Essential Techno 096',
#   'B',
#   110,
#   '+001 981 632-2966',
#   'Essential_Techno_096@outlook.com',
#   20130627,
#   98101,
#   'WA'),
#  ('98101-092',
#   'Digital Tech 032',
#   'C',
#   110,
#   '+001 981 759-5711',
#   'Digital_Tech_032@outlook.com',
#   20180219,
#   98101,
#   'WA'),
#  ('98101-093',
#   'Technologic Store 055',
#   'C',
#   110,
#   '+001 981 880-7453',
#   'Technologic_Store_055@outlook.com',
#   20040809,
#   98101,
#   'WA'),
#  ('98101-094',
#   'Computer Company 036',
#   'A',
#   110,
#   '+001 981 598-2831',
#   'Computer_Company_036@gmail.com.br',
#   20180930,
#   98101,
#   'WA'),
#  ('98101-095',
#   'Technologic Solutions 098',
#   'D',
#   110,
#   '+001 981 835-5141',
#   'Technologic_Solutions_098@gmail.com.br',
#   20100502,
#   98101,
#   'WA'),
#  ('98101-096',
#   'Digital Inc. 005',
#   'C',
#   110,
#   '+001 981 984-8108',
#   'Digital_Inc._005@gmail.com.br',
#   20010120,
#   98101,
#   'WA'),
#  ('98101-097',
#   'Essential Electronics 021',
#   'D',
#   110,
#   '+001 981 412-1157',
#   'Essential_Electronics_021@gmail.com.br',
#   20130704,
#   98101,
#   'WA'),
#  ('98101-098',
#   'High Tech Electronics 037',
#   'D',
#   110,
#   '+001 981 685-3641',
#   'High_Tech_Electronics_037@outlook.com',
#   20090701,
#   98101,
#   'WA'),
#  ('98101-099',
#   'Alpha Techno 096',
#   'B',
#   110,
#   '+001 981 755-2207',
#   'Alpha_Techno_096@outlook.com',
#   20170504,
#   98101,
#   'WA'),
#  ('98101-100',
#   'Beta World 044',
#   'C',
#   110,
#   '+001 981 623-1087',
#   'Beta_World_044@outlook.com',
#   20140511,
#   98101,
#   'WA')]

# %%
#create table 
def T_products():
    #read data
    products=pandas.read_csv("../NEW_DATASET/A01_TAB_PRODUCTS.csv",sep=';',decimal=',')
    
    #create table
    command="""CREATE TABLE PRODUCTS 
                (ID_PRODUCTS INTEGER UNIQUE,
                PROD_DESC VARCHAR,
                PROD_CLUSTER VARCHAR,
                UNITS_PACK INT,
                COST FLOAT,
                MARKUP FLOAT) """
    #cursor.execute(command) #create table in database

    #insert data
    command=''
    for register in products.values:
        register=f"""({register[0]},'{register[1]}','{register[2]}',{register[3]},{register[4]},{register[5]})"""
        command=command+','+register
    command=command[1:]
    command='INSERT INTO PRODUCTS VALUES '+command
    cursor.execute(command)
    banco.commit()

#T_products()

# %%
def table_price():
    t_price=pandas.read_csv("../NEW_DATASET/A02_TAB_PRICE.csv",sep=';',decimal=',')
    
    #create table
    command="""CREATE TABLE TAB_PRICE 
                (TABLE_ID VARCHAR UNIQUE,
                ID_products INT,
                tab_name CHAR,
                unit_price FLOAT) """
    #cursor.execute(command)
    command=''
    for register in t_price.values:
        command=command+','+f"""('{register[0]}',{register[1]},'{register[2]}',{register[3]})"""
    command=command[1:]
    command="INSERT INTO TAB_PRICE VALUES "+command
    cursor.execute(command)
    banco.commit()
#table_price()

# %%
def t_clients():
    clients=pandas.read_csv('../NEW_DATASET/A03_TAB_CLIENTS.csv',sep=';',decimal=',')

    command="""CREATE TABLE CLIENTS 
                (ID_client VARCHAR UNIQUE,
                name VARCHAR,
                cli_cluster VAR,
                ID_sector INT,
                phone VARCHAR,
                email VARCHAR,
                register_date INT,
                ZIPCODE INT,
                STATE VAR) """
    cursor.execute(command)

    command=''
    for register in clients.values:
        command=command+','+f"""('{register[0]}','{register[1]}','{register[2]}',{register[3]},
                                '{register[4]}','{register[5]}','{str(register[6]).replace('-','')}',{register[7]},
                                '{register[8]}') """
    command=command[1:]
    command='INSERT INTO CLIENTS VALUES '+command
    cursor.execute(command)
    banco.commit()

t_clients()
# Out:
#      ID_client                       name cluster  ID_sector  \
# 0    10001-001            Genius Inc. 032       D        201
# 1    10001-002   Father And Sons Tech 044       C        201
# 2    10001-003        Alpha Solutions 090       D        201
# 3    10001-004    Digital Corporation 096       D        201
# 4    10001-005       Beta Electronics 004       A        201
# ..         ...                        ...     ...        ...
# 594  98101-096           Digital Inc. 005       C        110
# 595  98101-097  Essential Electronics 021       D        110
# 596  98101-098  High Tech Electronics 037       D        110
# 597  98101-099           Alpha Techno 096       B        110
# 598  98101-100             Beta World 044       C        110
#
#                  phone                                   email register_date  \
# 0    +001 100 232-3005             Genius_Inc._032@outlook.com    2008-05-01
# 1    +001 100 936-9662    Father_And_Sons_Tech_044@outlook.com    2003-03-03
# 2    +001 100 611-2445         Alpha_Solutions_090@outlook.com    2014-06-05
# 3    +001 100 684-2310     Digital_Corporation_096@outlook.com    2020-03-01
# 4    +001 100 170-6120        Beta_Electronics_004@outlook.com    2012-11-14
# ..                 ...                                     ...           ...
# 594  +001 981 984-8108           Digital_Inc._005@gmail.com.br    2001-01-20
# 595  +001 981 412-1157  Essential_Electronics_021@gmail.com.br    2013-07-04
# 596  +001 981 685-3641   High_Tech_Electronics_037@outlook.com    2009-07-01
# 597  +001 981 755-2207            Alpha_Techno_096@outlook.com    2017-05-04
# 598  +001 981 623-1087              Beta_World_044@outlook.com    2014-05-11
#
#      zipcode state            city   No       street  visit_day
# 0      10001    NY   New York City    1      14th St        1.0
# 1      10001    NY   New York City  107  Chestnut St        2.0
# 2      10001    NY   New York City  152       8th St        3.0
# 3      10001    NY   New York City  165    Willow St        4.0
# 4      10001    NY   New York City  167       5th St        5.0
# ..       ...   ...             ...  ...          ...        ...
# 594    98101    WA         Seattle  974    Sunset St        5.0
# 595    98101    WA         Seattle  980    Walnut St        6.0
# 596    98101    WA         Seattle  981    Walnut St        7.0
# 597    98101    WA         Seattle  990      Hill St        1.0
# 598    98101    WA         Seattle  999   Madison St        2.0
#
# [599 rows x 13 columns]

# %%
def T_salesman():
    salesman=pandas.read_csv('../NEW_DATASET/A04_TAB_SALESMAN.csv',sep=';',decimal=',')

    command="""CREATE TABLE SALESMAN (
                        ID_sector INT UNIQUE,
                        Name VARCHAR,
                        supervisor INT
    )  """
    cursor.execute(command)
    command=''
    for register in salesman.values:
        command=command+','+f"""({register[0]},'{register[1]}',{register[2]}) """
    command=command[1:]
    command='INSERT INTO SALESMAN VALUES '+command

    print(command)

    cursor.execute(command)
    banco.commit()



    display(salesman)
#T_salesman()

# %%
def T_main_orders():
    order_main=pandas.read_csv('../NEW_DATASET/A05_TAB_ORDER_MAIN.csv',decimal=',',sep=';')

    command="""CREATE TABLE ORDER_MAIN (
    ID_CLIENT VARCHAR,
    ORDER_DATE INT,
    ORDER_NUMBER INT UNIQUE
    ) """
    cursor.execute(command)
    command=''
    for register in order_main.values:
        register=f"""('{register[0]}','{str(register[3]).replace('-','')}',{register[4]}) """
        command=command+','+register
    command=command[1:]
    command='INSERT INTO ORDER_MAIN VALUES '+command

    cursor.execute(command)
    banco.commit()


    display(order_main)

T_main_orders()
# Out:
#       ID_client cluster  ID_sector        Date       order_n
# 0     02215-015       C        109  2023-01-02  202301020001
# 1     02215-022       B        109  2023-01-02  202301020002
# 2     02215-029       D        109  2023-01-02  202301020003
# 3     04101-006       D        108  2023-01-02  202301020004
# 4     04101-043       D        108  2023-01-02  202301020005
# ...         ...     ...        ...         ...           ...
# 8651  98101-013       D        110  2023-04-29  202304290070
# 8652  98101-027       C        110  2023-04-29  202304290071
# 8653  98101-034       C        110  2023-04-29  202304290072
# 8654  98101-041       B        110  2023-04-29  202304290073
# 8655  98101-048       C        110  2023-04-29  202304290074
#
# [8656 rows x 5 columns]

# %%
def T_item_orders():
    item_order=pandas.read_csv('../NEW_DATASET/A06_TAB_ORDER_ITEM.csv',sep=';',decimal=',')

    command=""" CREATE TABLE ORDER_ITEM (
    order_n INT,
    ID_products INT,
    buy_packs INT,
    item_n INT,
    tab_price VARCHAR,
    ID VARCHAR UNIQUE
    ) """
    #cursor.execute(command)

    command=''
    for register in item_order.values:
        register=f"""({register[0]},{register[1]},{register[2]},
        {register[3]},'{register[4]}','{register[5]}') """
        command=command+','+register
    command=command[1:]
    command='INSERT INTO ORDER_ITEM VALUES '+command
    cursor.execute(command)
    banco.commit()


    display(item_order)
T_item_orders()
# Out:
#             order_n  ID_products  buy_packs  item_n tab_price  \
# 0      202301020001       901001       54.0       1     tab_2
# 1      202301020001       901003       30.0       2     tab_1
# 2      202301020001       901008        3.0       3     tab_1
# 3      202301020001       902004       63.0       4     tab_1
# 4      202301020001       902006       36.0       5     tab_1
# ...             ...          ...        ...     ...       ...
# 86547  202304290074       902012       72.0       4     tab_1
# 86548  202304290074       902015       66.0       5     tab_1
# 86549  202304290074       902017      204.0       6     tab_1
# 86550  202304290074       903009       27.0       7     tab_2
# 86551  202304290074       903018       15.0       8     tab_1
#
#                      ID
# 0      202301020001-001
# 1      202301020001-002
# 2      202301020001-003
# 3      202301020001-004
# 4      202301020001-005
# ...                 ...
# 86547  202304290074-004
# 86548  202304290074-005
# 86549  202304290074-006
# 86550  202304290074-007
# 86551  202304290074-008
#
# [86552 rows x 6 columns]
