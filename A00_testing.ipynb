# %%
class pdf_printer():
    def __init__(self,path='teste.pdf',
                 main_header='THIS IS THE HEADER',
                 sub_header='SUB HEADER',
                 footer='THIS IS THE FOOTER') -> None:
        self.head_foot=[main_header,sub_header,footer]
        
        from reportlab.platypus import SimpleDocTemplate
        self.doc=SimpleDocTemplate(path)
        self.story=[]
        self.__create_styles()

    def __create_styles(self):
        from reportlab.lib import colors
        from reportlab.platypus import TableStyle
        from reportlab.lib.styles import getSampleStyleSheet
        from reportlab.lib.units import inch

        def table_styles():
            #table styles
            
            tab_green = TableStyle([
            ('BACKGROUND', (0, 0), (-1, 0), colors.green),  # Cor de fundo para o cabeçalho
            ('TEXTCOLOR', (0, 0), (-1, 0), colors.black),  # Cor do texto do cabeçalho
            ('BACKGROUND', (0, 1), (-1, -1), colors.white),  # Cor de fundo para o conteúdo da tabela
            ('GRID',(0,0),(-1,-1),1,colors.black)
        ])
            tab_red = TableStyle([
            ('BACKGROUND', (0, 0), (-1, 0), colors.red),  # Cor de fundo para o cabeçalho
            ('TEXTCOLOR', (0, 0), (-1, 0), colors.black),  # Cor do texto do cabeçalho
            ('BACKGROUND', (0, 1), (-1, -1), colors.lightcoral),  # Cor de fundo para o conteúdo da tabela
            ('GRID',(0,0),(-1,-1),1,colors.black)
        ])
            self.style_table={
                'green':tab_green,
                'red':tab_red
            }
        table_styles()

        def paragraph_styles():
            
            #paragraph styles
            styles=getSampleStyleSheet()
            # Criando um novo estilo baseado no estilo 'Normal'
            from copy import deepcopy
            title = deepcopy(styles['Title'])
            title.textColor = colors.black  # Cor do texto
            title.fontName = 'Helvetica-Bold'
            title.borderColor = '#000000'  # Cor da borda
            title.borderWidth = 1  # Largura da borda
            title.borderPadding = (5, 5, 5, 5) 
            title.backColor=colors.lightgrey

            title2 = deepcopy(styles['Normal'])
            title2.leftIndent=-inch*0.7
            title2.rightIndent=-inch*0.7
            title2.borderColor = '#000000'  # Cor da borda
            title2.borderWidth = 1  # Largura da borda
            title2.borderPadding = (5, 5, 5, 5) 
            title2.backColor=colors.lightgrey

            title3 = deepcopy(styles['Normal'])
            title3.leftIndent=-inch*0.5
            title3.rightIndent=-inch*0.5
            title3.backColor=colors.lightgrey
            title3.borderPadding = (5, 5, 5, 5) 

            normal = deepcopy(styles['Normal'])
        
        
            self.style_paragraph={
                'title1':title,
                'title2':title2,
                'title3':title3,
                'normal':normal
            }
        paragraph_styles()
            
    def insert_paragraph(self,text='',style=''):
        from reportlab.platypus import  Paragraph
        if style=='':
            paragraph1 = Paragraph(text)
        else:
            style=self.style_paragraph[style]
            paragraph1 = Paragraph(text,style=style)
        self.story.append(paragraph1)

    def insert_spacer(self,size=0.2):
        from reportlab.platypus import Spacer
        from reportlab.lib.units import inch
        self.story.append(Spacer(width=inch*size,height=inch*size))

    def insert_table(self,dataframe,style='green'):
        style=self.style_table[style]
        from reportlab.platypus import Table
        data = [dataframe.columns.values.tolist()] + dataframe.values.tolist()
        new_table=Table(data,style=style)
        self.story.append(new_table)

    def save_document(self,path='./teste.pdf'):
        path=path
        self.doc.build(self.story,onFirstPage=self.page_head_foot, onLaterPages=self.page_head_foot)

    def page_head_foot(self,canvas,doc):
        from reportlab.lib.units import mm
        from reportlab.platypus import  Image
        page_num = canvas.getPageNumber()
        pg_numb = "Page #%s" % page_num
        canvas.drawRightString(200*mm, 20*mm, pg_numb) #page number


        canvas.drawRightString(60*mm, 285*mm, self.head_foot[0]) #Main header
        canvas.drawRightString(60*mm, 277*mm, self.head_foot[1]) #Sub header
        canvas.drawRightString(60*mm, 20*mm, self.head_foot[2]) #Footer
        canvas.drawImage('./C1_REPORTS_SCRIPTS/A_toolbox/PDF_report/IMAGES/basic_logo.png', 185*mm, 280*mm, width=15*mm, height=15*mm)
    

    def jump_page(self):
        from reportlab.platypus import  PageBreak
        self.story.append(PageBreak())
        
import numpy as np
import pandas
data = np.random.randint(1, 100, size=(5, 5)).tolist()
data=pandas.DataFrame(data,columns=['A','B','C','D','E'])


report_pdf=pdf_printer()
report_pdf.insert_paragraph(text='TITLE OF THE REPORT',style='title1')
report_pdf.insert_spacer()
report_pdf.insert_paragraph(text='SUB TITLE',style='title2')
report_pdf.insert_spacer()
report_pdf.insert_paragraph(text='TEXT',style='title3')
report_pdf.insert_spacer()
report_pdf.insert_paragraph(text='TEXT',style='normal')
report_pdf.insert_spacer()
report_pdf.insert_paragraph()
report_pdf.insert_table(dataframe=data)
report_pdf.jump_page()
report_pdf.insert_table(dataframe=data)

report_pdf.save_document(path='')

# %%
from reportlab.lib.styles import getSampleStyleSheet
styles=getSampleStyleSheet()
for i in styles.list():
    print(i)

print(styles['normal'].list())
# Out:
# BodyText None
#     name = BodyText
#     parent = <ParagraphStyle 'Normal'>
#     alignment = 0
#     allowOrphans = 0
#     allowWidows = 1
#     backColor = None
#     borderColor = None
#     borderPadding = 0
#     borderRadius = None
#     borderWidth = 0
#     bulletAnchor = start
#     bulletFontName = Helvetica
#     bulletFontSize = 10
#     bulletIndent = 0
#     embeddedHyphenation = 0
#     endDots = None
#     firstLineIndent = 0
#     fontName = Helvetica
#     fontSize = 10
#     hyphenationLang =
#     justifyBreaks = 0
#     justifyLastLine = 0
#     leading = 12
#     leftIndent = 0
#     linkUnderline = 0
#     rightIndent = 0
#     spaceAfter = 0
#     spaceBefore = 6
#     spaceShrinkage = 0.05
#     splitLongWords = 1
#     strikeColor = None
#     strikeGap = 1
#     strikeOffset = 0.25*F
#     strikeWidth =
#     textColor = Color(0,0,0,1)
#     textTransform = None
#     underlineColor = None
#     underlineGap = 1
#     underlineOffset = -0.125*F
#     underlineWidth =
#     uriWasteReduce = 0
#     wordWrap = None
#
# Bullet bu
#     name = Bullet
#     parent = <ParagraphStyle 'Normal'>
#     alignment = 0
#     allowOrphans = 0
#     allowWidows = 1
#     backColor = None
#     borderColor = None
#     borderPadding = 0
#     borderRadius = None
#     borderWidth = 0
#     bulletAnchor = start
#     bulletFontName = Helvetica
#     bulletFontSize = 10
#     bulletIndent = 0
#     embeddedHyphenation = 0
#     endDots = None
#     firstLineIndent = 0
#     fontName = Helvetica
#     fontSize = 10
#     hyphenationLang =
#     justifyBreaks = 0
#     justifyLastLine = 0
#     leading = 12
#     leftIndent = 0
#     linkUnderline = 0
#     rightIndent = 0
#     spaceAfter = 0
#     spaceBefore = 3
#     spaceShrinkage = 0.05
#     splitLongWords = 1
#     strikeColor = None
#     strikeGap = 1
#     strikeOffset = 0.25*F
#     strikeWidth =
#     textColor = Color(0,0,0,1)
#     textTransform = None
#     underlineColor = None
#     underlineGap = 1
#     underlineOffset = -0.125*F
#     underlineWidth =
#     uriWasteReduce = 0
#     wordWrap = None
#
# Code None
#     name = Code
#     parent = <ParagraphStyle 'Normal'>
#     alignment = 0
#     allowOrphans = 0
#     allowWidows = 1
#     backColor = None
#     borderColor = None
#     borderPadding = 0
#     borderRadius = None
#     borderWidth = 0
#     bulletAnchor = start
#     bulletFontName = Helvetica
#     bulletFontSize = 10
#     bulletIndent = 0
#     embeddedHyphenation = 0
#     endDots = None
#     firstLineIndent = 0
#     fontName = Courier
#     fontSize = 8
#     hyphenationLang =
#     justifyBreaks = 0
#     justifyLastLine = 0
#     leading = 8.8
#     leftIndent = 36
#     linkUnderline = 0
#     rightIndent = 0
#     spaceAfter = 0
#     spaceBefore = 0
#     spaceShrinkage = 0.05
#     splitLongWords = 1
#     strikeColor = None
#     strikeGap = 1
#     strikeOffset = 0.25*F
#     strikeWidth =
#     textColor = Color(0,0,0,1)
#     textTransform = None
#     underlineColor = None
#     underlineGap = 1
#     underlineOffset = -0.125*F
#     underlineWidth =
#     uriWasteReduce = 0
#     wordWrap = None
#
# Definition df
#     name = Definition
#     parent = <ParagraphStyle 'Normal'>
#     alignment = 0
#     allowOrphans = 0
#     allowWidows = 1
#     backColor = None
#     borderColor = None
#     borderPadding = 0
#     borderRadius = None
#     borderWidth = 0
#     bulletAnchor = start
#     bulletFontName = Helvetica-BoldOblique
#     bulletFontSize = 10
#     bulletIndent = 0
#     embeddedHyphenation = 0
#     endDots = None
#     firstLineIndent = 0
#     fontName = Helvetica
#     fontSize = 10
#     hyphenationLang =
#     justifyBreaks = 0
#     justifyLastLine = 0
#     leading = 12
#     leftIndent = 36
#     linkUnderline = 0
#     rightIndent = 0
#     spaceAfter = 0
#     spaceBefore = 6
#     spaceShrinkage = 0.05
#     splitLongWords = 1
#     strikeColor = None
#     strikeGap = 1
#     strikeOffset = 0.25*F
#     strikeWidth =
#     textColor = Color(0,0,0,1)
#     textTransform = None
#     underlineColor = None
#     underlineGap = 1
#     underlineOffset = -0.125*F
#     underlineWidth =
#     uriWasteReduce = 0
#     wordWrap = None
#
# Heading1 h1
#     name = Heading1
#     parent = <ParagraphStyle 'Normal'>
#     alignment = 0
#     allowOrphans = 0
#     allowWidows = 1
#     backColor = None
#     borderColor = None
#     borderPadding = 0
#     borderRadius = None
#     borderWidth = 0
#     bulletAnchor = start
#     bulletFontName = Helvetica
#     bulletFontSize = 10
#     bulletIndent = 0
#     embeddedHyphenation = 0
#     endDots = None
#     firstLineIndent = 0
#     fontName = Helvetica-Bold
#     fontSize = 18
#     hyphenationLang =
#     justifyBreaks = 0
#     justifyLastLine = 0
#     leading = 22
#     leftIndent = 0
#     linkUnderline = 0
#     rightIndent = 0
#     spaceAfter = 6
#     spaceBefore = 0
#     spaceShrinkage = 0.05
#     splitLongWords = 1
#     strikeColor = None
#     strikeGap = 1
#     strikeOffset = 0.25*F
#     strikeWidth =
#     textColor = Color(0,0,0,1)
#     textTransform = None
#     underlineColor = None
#     underlineGap = 1
#     underlineOffset = -0.125*F
#     underlineWidth =
#     uriWasteReduce = 0
#     wordWrap = None
#
# Heading2 h2
#     name = Heading2
#     parent = <ParagraphStyle 'Normal'>
#     alignment = 0
#     allowOrphans = 0
#     allowWidows = 1
#     backColor = None
#     borderColor = None
#     borderPadding = 0
#     borderRadius = None
#     borderWidth = 0
#     bulletAnchor = start
#     bulletFontName = Helvetica
#     bulletFontSize = 10
#     bulletIndent = 0
#     embeddedHyphenation = 0
#     endDots = None
#     firstLineIndent = 0
#     fontName = Helvetica-Bold
#     fontSize = 14
#     hyphenationLang =
#     justifyBreaks = 0
#     justifyLastLine = 0
#     leading = 18
#     leftIndent = 0
#     linkUnderline = 0
#     rightIndent = 0
#     spaceAfter = 6
#     spaceBefore = 12
#     spaceShrinkage = 0.05
#     splitLongWords = 1
#     strikeColor = None
#     strikeGap = 1
#     strikeOffset = 0.25*F
#     strikeWidth =
#     textColor = Color(0,0,0,1)
#     textTransform = None
#     underlineColor = None
#     underlineGap = 1
#     underlineOffset = -0.125*F
#     underlineWidth =
#     uriWasteReduce = 0
#     wordWrap = None
#
# Heading3 h3
#     name = Heading3
#     parent = <ParagraphStyle 'Normal'>
#     alignment = 0
#     allowOrphans = 0
#     allowWidows = 1
#     backColor = None
#     borderColor = None
#     borderPadding = 0
#     borderRadius = None
#     borderWidth = 0
#     bulletAnchor = start
#     bulletFontName = Helvetica
#     bulletFontSize = 10
#     bulletIndent = 0
#     embeddedHyphenation = 0
#     endDots = None
#     firstLineIndent = 0
#     fontName = Helvetica-BoldOblique
#     fontSize = 12
#     hyphenationLang =
#     justifyBreaks = 0
#     justifyLastLine = 0
#     leading = 14
#     leftIndent = 0
#     linkUnderline = 0
#     rightIndent = 0
#     spaceAfter = 6
#     spaceBefore = 12
#     spaceShrinkage = 0.05
#     splitLongWords = 1
#     strikeColor = None
#     strikeGap = 1
#     strikeOffset = 0.25*F
#     strikeWidth =
#     textColor = Color(0,0,0,1)
#     textTransform = None
#     underlineColor = None
#     underlineGap = 1
#     underlineOffset = -0.125*F
#     underlineWidth =
#     uriWasteReduce = 0
#     wordWrap = None
#
# Heading4 h4
#     name = Heading4
#     parent = <ParagraphStyle 'Normal'>
#     alignment = 0
#     allowOrphans = 0
#     allowWidows = 1
#     backColor = None
#     borderColor = None
#     borderPadding = 0
#     borderRadius = None
#     borderWidth = 0
#     bulletAnchor = start
#     bulletFontName = Helvetica
#     bulletFontSize = 10
#     bulletIndent = 0
#     embeddedHyphenation = 0
#     endDots = None
#     firstLineIndent = 0
#     fontName = Helvetica-BoldOblique
#     fontSize = 10
#     hyphenationLang =
#     justifyBreaks = 0
#     justifyLastLine = 0
#     leading = 12
#     leftIndent = 0
#     linkUnderline = 0
#     rightIndent = 0
#     spaceAfter = 4
#     spaceBefore = 10
#     spaceShrinkage = 0.05
#     splitLongWords = 1
#     strikeColor = None
#     strikeGap = 1
#     strikeOffset = 0.25*F
#     strikeWidth =
#     textColor = Color(0,0,0,1)
#     textTransform = None
#     underlineColor = None
#     underlineGap = 1
#     underlineOffset = -0.125*F
#     underlineWidth =
#     uriWasteReduce = 0
#     wordWrap = None
#
# Heading5 h5
#     name = Heading5
#     parent = <ParagraphStyle 'Normal'>
#     alignment = 0
#     allowOrphans = 0
#     allowWidows = 1
#     backColor = None
#     borderColor = None
#     borderPadding = 0
#     borderRadius = None
#     borderWidth = 0
#     bulletAnchor = start
#     bulletFontName = Helvetica
#     bulletFontSize = 10
#     bulletIndent = 0
#     embeddedHyphenation = 0
#     endDots = None
#     firstLineIndent = 0
#     fontName = Helvetica-Bold
#     fontSize = 9
#     hyphenationLang =
#     justifyBreaks = 0
#     justifyLastLine = 0
#     leading = 10.8
#     leftIndent = 0
#     linkUnderline = 0
#     rightIndent = 0
#     spaceAfter = 4
#     spaceBefore = 8
#     spaceShrinkage = 0.05
#     splitLongWords = 1
#     strikeColor = None
#     strikeGap = 1
#     strikeOffset = 0.25*F
#     strikeWidth =
#     textColor = Color(0,0,0,1)
#     textTransform = None
#     underlineColor = None
#     underlineGap = 1
#     underlineOffset = -0.125*F
#     underlineWidth =
#     uriWasteReduce = 0
#     wordWrap = None
#
# Heading6 h6
#     name = Heading6
#     parent = <ParagraphStyle 'Normal'>
#     alignment = 0
#     allowOrphans = 0
#     allowWidows = 1
#     backColor = None
#     borderColor = None
#     borderPadding = 0
#     borderRadius = None
#     borderWidth = 0
#     bulletAnchor = start
#     bulletFontName = Helvetica
#     bulletFontSize = 10
#     bulletIndent = 0
#     embeddedHyphenation = 0
#     endDots = None
#     firstLineIndent = 0
#     fontName = Helvetica-Bold
#     fontSize = 7
#     hyphenationLang =
#     justifyBreaks = 0
#     justifyLastLine = 0
#     leading = 8.4
#     leftIndent = 0
#     linkUnderline = 0
#     rightIndent = 0
#     spaceAfter = 2
#     spaceBefore = 6
#     spaceShrinkage = 0.05
#     splitLongWords = 1
#     strikeColor = None
#     strikeGap = 1
#     strikeOffset = 0.25*F
#     strikeWidth =
#     textColor = Color(0,0,0,1)
#     textTransform = None
#     underlineColor = None
#     underlineGap = 1
#     underlineOffset = -0.125*F
#     underlineWidth =
#     uriWasteReduce = 0
#     wordWrap = None
#
# Italic None
#     name = Italic
#     parent = <ParagraphStyle 'BodyText'>
#     alignment = 0
#     allowOrphans = 0
#     allowWidows = 1
#     backColor = None
#     borderColor = None
#     borderPadding = 0
#     borderRadius = None
#     borderWidth = 0
#     bulletAnchor = start
#     bulletFontName = Helvetica
#     bulletFontSize = 10
#     bulletIndent = 0
#     embeddedHyphenation = 0
#     endDots = None
#     firstLineIndent = 0
#     fontName = Helvetica-Oblique
#     fontSize = 10
#     hyphenationLang =
#     justifyBreaks = 0
#     justifyLastLine = 0
#     leading = 12
#     leftIndent = 0
#     linkUnderline = 0
#     rightIndent = 0
#     spaceAfter = 0
#     spaceBefore = 6
#     spaceShrinkage = 0.05
#     splitLongWords = 1
#     strikeColor = None
#     strikeGap = 1
#     strikeOffset = 0.25*F
#     strikeWidth =
#     textColor = Color(0,0,0,1)
#     textTransform = None
#     underlineColor = None
#     underlineGap = 1
#     underlineOffset = -0.125*F
#     underlineWidth =
#     uriWasteReduce = 0
#     wordWrap = None
#
# Normal None
#     name = Normal
#     parent = None
#     alignment = 0
#     allowOrphans = 0
#     allowWidows = 1
#     backColor = None
#     borderColor = None
#     borderPadding = 0
#     borderRadius = None
#     borderWidth = 0
#     bulletAnchor = start
#     bulletFontName = Helvetica
#     bulletFontSize = 10
#     bulletIndent = 0
#     embeddedHyphenation = 0
#     endDots = None
#     firstLineIndent = 0
#     fontName = Helvetica
#     fontSize = 10
#     hyphenationLang =
#     justifyBreaks = 0
#     justifyLastLine = 0
#     leading = 12
#     leftIndent = 0
#     linkUnderline = 0
#     rightIndent = 0
#     spaceAfter = 0
#     spaceBefore = 0
#     spaceShrinkage = 0.05
#     splitLongWords = 1
#     strikeColor = None
#     strikeGap = 1
#     strikeOffset = 0.25*F
#     strikeWidth =
#     textColor = Color(0,0,0,1)
#     textTransform = None
#     underlineColor = None
#     underlineGap = 1
#     underlineOffset = -0.125*F
#     underlineWidth =
#     uriWasteReduce = 0
#     wordWrap = None
#
# OrderedList ol
#     name = OrderedList
#     parent = None
#     bulletAlign = left
#     bulletColor = Color(0,0,0,1)
#     bulletDedent = auto
#     bulletDir = ltr
#     bulletFontName = Helvetica
#     bulletFontSize = 12
#     bulletFormat = None
#     bulletOffsetY = 0
#     bulletType = 1
#     leftIndent = 18
#     rightIndent = 0
#     start = None
#
# Title title
#     name = Title
#     parent = <ParagraphStyle 'Normal'>
#     alignment = 1
#     allowOrphans = 0
#     allowWidows = 1
#     backColor = None
#     borderColor = None
#     borderPadding = 0
#     borderRadius = None
#     borderWidth = 0
#     bulletAnchor = start
#     bulletFontName = Helvetica
#     bulletFontSize = 10
#     bulletIndent = 0
#     embeddedHyphenation = 0
#     endDots = None
#     firstLineIndent = 0
#     fontName = Helvetica-Bold
#     fontSize = 18
#     hyphenationLang =
#     justifyBreaks = 0
#     justifyLastLine = 0
#     leading = 22
#     leftIndent = 0
#     linkUnderline = 0
#     rightIndent = 0
#     spaceAfter = 6
#     spaceBefore = 0
#     spaceShrinkage = 0.05
#     splitLongWords = 1
#     strikeColor = None
#     strikeGap = 1
#     strikeOffset = 0.25*F
#     strikeWidth =
#     textColor = Color(0,0,0,1)
#     textTransform = None
#     underlineColor = None
#     underlineGap = 1
#     underlineOffset = -0.125*F
#     underlineWidth =
#     uriWasteReduce = 0
#     wordWrap = None
#
# UnorderedList ul
#     name = UnorderedList
#     parent = None
#     bulletAlign = left
#     bulletColor = Color(0,0,0,1)
#     bulletDedent = auto
#     bulletDir = ltr
#     bulletFontName = Helvetica
#     bulletFontSize = 12
#     bulletFormat = None
#     bulletOffsetY = 0
#     bulletType = 1
#     leftIndent = 18
#     rightIndent = 0
#     start = None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/matheus/Área de Trabalho/portfólio/comecial_analytics/A00_testing.ipynb Cell 2 line 3
#       <a href='vscode-notebook-cell:/home/matheus/%C3%81rea%20de%20Trabalho/portf%C3%B3lio/comecial_analytics/A00_testing.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> from reportlab.lib.styles import getSampleStyleSheet
#       <a href='vscode-notebook-cell:/home/matheus/%C3%81rea%20de%20Trabalho/portf%C3%B3lio/comecial_analytics/A00_testing.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> styles=getSampleStyleSheet()
# ----> <a href='vscode-notebook-cell:/home/matheus/%C3%81rea%20de%20Trabalho/portf%C3%B3lio/comecial_analytics/A00_testing.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> for i in styles.list():
#       <a href='vscode-notebook-cell:/home/matheus/%C3%81rea%20de%20Trabalho/portf%C3%B3lio/comecial_analytics/A00_testing.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a>     print(i)
#       <a href='vscode-notebook-cell:/home/matheus/%C3%81rea%20de%20Trabalho/portf%C3%B3lio/comecial_analytics/A00_testing.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a> print(styles['normal'].list())
#
# TypeError: 'NoneType' object is not iterable
